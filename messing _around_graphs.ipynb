# %%
import networkx as nx
import pandas as pd
from collections import Counter, defaultdict
from tqdm import tqdm
import os
import pickle
import hashlib

# %% [markdown]
# #### LOAD IN BIG GRAPH

# %%
G = nx.read_graphml(f"procurement_graph_none.graphml")
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1029f1c40>>
# Traceback (most recent call last):
#   File "/Users/wiktorrajca/Library/Python/3.9/lib/python/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:

# %%
len(G.nodes)
len(G.edges)
# Out:
# 7880318

# %% [markdown]
# #### SPLIT BIG GRAPH BY COUNTRY

# %%
def split_graph_by_country(G, output_dir="graphs_by_country_optimized"):
    import os
    from tqdm import tqdm
    os.makedirs(output_dir, exist_ok=True)

    # Step 1: Group winner nodes by country
    country_winners = {}
    for node, data in tqdm(G.nodes(data=True), desc="Grouping nodes by country"):
        if data.get("type") == "Company" and data.get("bid_winner"):
            country = str(data.get("win_country_code", "Unknown"))[:2]
            country_winners.setdefault(country, []).append(node)

    # Step 2: Build a neighbor map only once
    print("⚙️  Indexing neighbors...")
    neighbor_map = {}
    for node in tqdm(G.nodes(), desc="Indexing neighbors"):
        neighbors = set(G.successors(node)).union(G.predecessors(node))
        neighbor_map[node] = neighbors

    # Step 3: Build subgraphs efficiently using neighbor map
    split_graphs = {}
    for country, nodes in tqdm(country_winners.items(), desc="Creating subgraphs"):
        sub_nodes = set(nodes)  # start with winner nodes
        for node in nodes:
            sub_nodes.update(neighbor_map.get(node, set()))  # add all neighbors

        subgraph = G.subgraph(sub_nodes).copy()
        split_graphs[country] = subgraph

        path = os.path.join(output_dir, f"graph_{country}.graphml")
        nx.write_graphml(subgraph, path)
        tqdm.write(f"✅ Saved {country} ({len(subgraph.nodes)} nodes) → {path}")

    return split_graphs

# %%
split_graph_by_country(G)
# Out:
# Grouping nodes by country: 100%|██████████| 11524092/11524092 [01:07<00:00, 170283.96it/s]
# ⚙️  Indexing neighbors...
# Indexing neighbors: 100%|██████████| 11524092/11524092 [09:31<00:00, 20168.74it/s]
# Creating subgraphs:   1%|          | 1/175 [22:27<65:08:53, 1347.90s/it]
# ✅ Saved fr (2469037 nodes) → graphs_by_country_optimized/graph_fr.graphml
# Creating subgraphs:   1%|          | 2/175 [27:36<35:23:47, 736.57s/it]
# ✅ Saved it (788162 nodes) → graphs_by_country_optimized/graph_it.graphml
# Creating subgraphs:   2%|▏         | 3/175 [47:07<44:40:40, 935.12s/it]
# ✅ Saved Un (2505154 nodes) → graphs_by_country_optimized/graph_Un.graphml
# Creating subgraphs:   2%|▏         | 4/175 [47:39<27:28:57, 578.58s/it]
# ✅ Saved ro (150557 nodes) → graphs_by_country_optimized/graph_ro.graphml
# Creating subgraphs:   3%|▎         | 5/175 [58:03<28:05:03, 594.73s/it]
# ✅ Saved uk (1138472 nodes) → graphs_by_country_optimized/graph_uk.graphml
# Creating subgraphs:   3%|▎         | 6/175 [1:12:13<32:00:06, 681.69s/it]
# ✅ Saved de (597563 nodes) → graphs_by_country_optimized/graph_de.graphml
# Creating subgraphs:   4%|▍         | 7/175 [1:12:56<22:03:59, 472.85s/it]
# ✅ Saved be (241085 nodes) → graphs_by_country_optimized/graph_be.graphml
# Creating subgraphs:   5%|▍         | 8/175 [1:13:11<15:10:09, 327.00s/it]
# ✅ Saved dk (122199 nodes) → graphs_by_country_optimized/graph_dk.graphml
# Creating subgraphs:   5%|▌         | 9/175 [1:17:02<13:42:04, 297.14s/it]
# ✅ Saved se (98569 nodes) → graphs_by_country_optimized/graph_se.graphml
# Creating subgraphs:   6%|▌         | 10/175 [1:17:31<9:49:23, 214.33s/it]
# ✅ Saved pl (220183 nodes) → graphs_by_country_optimized/graph_pl.graphml
# Creating subgraphs:   6%|▋         | 11/175 [1:21:00<9:41:21, 212.69s/it]
# ✅ Saved nl (283254 nodes) → graphs_by_country_optimized/graph_nl.graphml
# Creating subgraphs:   7%|▋         | 12/175 [1:21:22<7:00:23, 154.75s/it]
# ✅ Saved no (119157 nodes) → graphs_by_country_optimized/graph_no.graphml
# Creating subgraphs:   7%|▋         | 13/175 [1:21:23<4:51:29, 107.96s/it]
# ✅ Saved in (2181 nodes) → graphs_by_country_optimized/graph_in.graphml
# Creating subgraphs:   8%|▊         | 14/175 [1:21:27<3:25:45, 76.68s/it]
# ✅ Saved hr (35738 nodes) → graphs_by_country_optimized/graph_hr.graphml
# Creating subgraphs:   9%|▊         | 15/175 [1:21:35<2:29:05, 55.91s/it]
# ✅ Saved at (79446 nodes) → graphs_by_country_optimized/graph_at.graphml
# Creating subgraphs:   9%|▉         | 16/175 [1:24:08<3:45:58, 85.27s/it]
# ✅ Saved us (89428 nodes) → graphs_by_country_optimized/graph_us.graphml
# Creating subgraphs:  10%|▉         | 17/175 [1:24:23<2:48:31, 63.99s/it]
# ✅ Saved cz (139029 nodes) → graphs_by_country_optimized/graph_cz.graphml
# ✅ Saved om (20 nodes) → graphs_by_country_optimized/graph_om.graphml
# Creating subgraphs:  11%|█         | 19/175 [1:24:23<1:29:46, 34.53s/it]
# ✅ Saved cn (3404 nodes) → graphs_by_country_optimized/graph_cn.graphml
# Creating subgraphs:  11%|█▏        | 20/175 [1:24:27<1:09:37, 26.95s/it]
# ✅ Saved pt (60978 nodes) → graphs_by_country_optimized/graph_pt.graphml
# Creating subgraphs:  12%|█▏        | 21/175 [1:24:43<1:01:24, 23.92s/it]
# ✅ Saved ie (151803 nodes) → graphs_by_country_optimized/graph_ie.graphml

# %%
Gf = nx.read_graphml(f"graphs_by_country_optimized/graph_fr.graphml")

# %%
print("Nodes ",len(Gf.nodes))
print("Edges ", len(Gf.edges))
# Out:
# Nodes  2469037
# Edges  1651874

# %% [markdown]
# #### SUMMARIZE GRAPH

# %%
def summarize_graph(G):
    print("\n===== Graph Summary =====")
    print(f"Total Nodes: {len(G.nodes)}")
    print(f"Total Edges: {len(G.edges)}")

    node_types = [G.nodes[n].get("type", "Unknown") for n in G.nodes]
    node_type_counts = Counter(node_types)
    print("\nNode Types:")
    for node_type, count in node_type_counts.items():
        print(f"  - {node_type}: {count}")

    edge_relationships = [G.edges[e].get("relationship", "Unknown") for e in G.edges]
    edge_type_counts = Counter(edge_relationships)
    print("\nEdge Types:")
    for rel, count in edge_type_counts.items():
        print(f"  - {rel}: {count}")

    flagged_count = sum(1 for n in G.nodes if G.nodes[n].get("flagged") == 'True')
    print(f"\nFlagged Companies: {flagged_count}")
    print("=========================\n")

# %%
summarize_graph(Gf)
# Out:
# ===== Graph Summary =====
# Total Nodes: 2469037
# Total Edges: 1651874
#
# Node Types:
#   - Company: 1150169
#   - Procurement: 1318863
#   - Flagged: 5
#
# Edge Types:
#   - WON: 1318863
#   - CONTROLS: 34460
#   - OWNS: 298340
#   - SUBSIDIARY_OF: 122
#   - FLAGGED_LINK: 89
#
# Flagged Companies: 14078
# =========================

# %%
def summarize_flagged_entity_relations_separately(G, top_k=10):
    print("===== FLAGGED ENTITY RELATION SUMMARY (by type) =====")

    flagged_companies = {}
    flagged_people = {}

    for node, data in tqdm(G.nodes(data=True), desc="Scanning nodes", unit="node"):
        if data.get("flagged") == "True" and data.get("type") == "Company":
            flagged_companies[node] = data.get("name", "Unknown")
        elif data.get("type") == "Flagged":
            flagged_people[node] = data.get("name", "Unknown")

    won_counts = defaultdict(int)
    owns_counts = defaultdict(int)
    controls_counts = defaultdict(int)
    subsidiary_counts = defaultdict(int)
    flagged_links = defaultdict(set)

    for u, v, d in tqdm(G.edges(data=True), desc="Scanning edges", unit="edge"):
        rel = d.get("relationship")
        if rel == "WON" and u in flagged_companies:
            won_counts[u] += 1
        if rel == "OWNS" and u in flagged_companies:
            owns_counts[u] += 1
        if rel == "CONTROLS" and u in flagged_companies:
            controls_counts[u] += 1
        if rel == "SUBSIDIARY_OF" and u in flagged_companies:
            subsidiary_counts[u] += 1
        if rel == "FLAGGED_LINK" and u in flagged_people:
            flagged_links[u].add(v)

    def print_top(mapping, label, name_map):
        print(f"\nTop {top_k} by {label}:")
        top = sorted(mapping.items(), key=lambda x: x[1] if isinstance(x[1], int) else len(x[1]), reverse=True)[:top_k]
        df = pd.DataFrame([
            {
                "Name": name_map.get(k, "Unknown"),
                "ID": k,
                label: v if isinstance(v, int) else len(v)
            }
            for k, v in top
        ])
        print(df.to_string(index=False))

    print(f"\nFlagged Companies Total: {len(flagged_companies)}")
    print(f"Flagged People Total: {len(flagged_people)}")

    print(f"\nFlagged Companies with WON edges: {len(won_counts)}")
    print(f"Flagged Companies with OWNS edges: {len(owns_counts)}")
    print(f"Flagged Companies with CONTROLS edges: {len(controls_counts)}")
    print(f"Flagged Companies with SUBSIDIARY_OF edges: {len(subsidiary_counts)}")
    print(f"Flagged People with FLAGGED_LINK connections: {len(flagged_links)}")

    print_top(won_counts, "Contracts Won", flagged_companies)
    print_top(owns_counts, "Companies Owned", flagged_companies)
    print_top(controls_counts, "Companies Controlled", flagged_companies)
    print_top(subsidiary_counts, "Subsidiary Links", flagged_companies)
    print_top(flagged_links, "Linked Companies", flagged_people)

    print("\n===== END OF SUMMARY =====\n")

# %%
sanc = pd.read_csv("/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/data/Black_Lists/Black_Lists_Data_Sets/open_sanctions.csv")
count_contains = sanc['name'].str.contains('SDS', na=False).sum()
count_exact = (sanc['name'] == 'SDS').sum()
print(count_contains, count_exact)
# Out:
# 8 1
# /var/folders/r2/9vnxdxyd26380tms_8k538b40000gn/T/ipykernel_1517/3005866531.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sanc = pd.read_csv("/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/data/Black_Lists/Black_Lists_Data_Sets/open_sanctions.csv")

# %%
import pandas as pd
from collections import defaultdict
import re

def summarize_flagged_entities_to_csv(G, output_path="flagged_entity_summary.csv"):
    """
    Summarizes flagged companies and people along with their graph relationships (WON, OWNS, CONTROLS, etc.).
    Outputs the summary as a CSV.
    
    Parameters:
        G (networkx.Graph): The input graph.
        output_path (str): File path to save the summary CSV.
    
    Returns:
        pd.DataFrame: The summary DataFrame.
    """
    flagged_summary = []

    for node, data in G.nodes(data=True):
        if data.get("flagged") == "True" or data.get("type") == "Flagged":
            node_id = node
            node_type = data.get("type", "Unknown")
            name = data.get("name", "Unknown")

            # Try to extract the sanction_id if present in flagged_reason
            flagged_reason = data.get("flagged_reason", "")
            match = re.search(r"Matched to flagged entity (\S+)", flagged_reason)
            sanction_id = match.group(1) if match else ""

            # Count relationships from this node
            won_count = 0
            owns_count = 0
            controls_count = 0
            subsidiary_count = 0
            flagged_links = 0

            for _, tgt, edata in G.out_edges(node, data=True):
                rel = edata.get("relationship")
                if rel == "WON":
                    won_count += 1
                elif rel == "OWNS":
                    owns_count += 1
                elif rel == "CONTROLS":
                    controls_count += 1
                elif rel == "SUBSIDIARY_OF":
                    subsidiary_count += 1
                elif rel == "FLAGGED_LINK":
                    flagged_links += 1

            for src, _, edata in G.in_edges(node, data=True):
                rel = edata.get("relationship")
                if rel == "FLAGGED_LINK":
                    flagged_links += 1

            flagged_summary.append({
                "ID": node_id,
                "Sanction_ID": sanction_id,
                "Name": name,
                "Type": node_type,
                "Contracts_Won": won_count,
                "Owns_Companies": owns_count,
                "Controls_Companies": controls_count,
                "Subsidiary_Links": subsidiary_count,
                "Flagged_Links": flagged_links
            })

    df = pd.DataFrame(flagged_summary)
    df.to_csv(output_path, index=False)
    print(f"✅ Summary saved to {output_path}")
    return df

# %%
df = summarize_flagged_entities_to_csv(Gf)
# Out:
# ✅ Summary saved to flagged_entity_summary.csv

# %%
df
# Out:
#                  ID                Sanction_ID            Name     Type  \
# 0        RU79752370            usgsa-s4mr55c8r           Smart  Company
# 1       RU40924122N  NK-4ZURfkkRkubWm2FfdVqq3F          Altair  Company
# 2        RU36275132  NK-4ZURfkkRkubWm2FfdVqq3F          Altair  Company
# 3       RU34543568N  NK-Gbik6Hp3G8o9nPkMzyq68M         Antares  Company
# 4        RU05255392  NK-Gbik6Hp3G8o9nPkMzyq68M         Antares  Company
# ...             ...                        ...             ...      ...
# 14078  US126303612L            usgsa-s4mr3pyw9        PCI Corp  Company
# 14079  US131748537L            usgsa-s4mr3pyw9             PCI  Company
# 14080    RU44258076            usgsa-s4mr3p1vn             SDS  Company
# 14081  US257613749L            usgsa-s4mr3pr2j  M.I.R.A., Inc.  Company
# 14082    RU25523294  NK-Gbik6Hp3G8o9nPkMzyq68M         Antares  Company
#
#        Contracts_Won  Owns_Companies  Controls_Companies  Subsidiary_Links  \
# 0                  1               0                   0                 0
# 1                  2               0                   0                 0
# 2                  2               1                   0                 0
# 3                  1               0                   0                 0
# 4                  1               0                   0                 0
# ...              ...             ...                 ...               ...
# 14078              1               0                   0                 0
# 14079              1               0                   0                 0
# 14080              3               0                   0                 0
# 14081              1               0                   0                 0
# 14082              1               0                   0                 0
#
#        Flagged_Links
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 14078              0
# 14079              0
# 14080              0
# 14081              0
# 14082              0
#
# [14083 rows x 9 columns]

# %% [markdown]
# #### LOOKING INTO GRAPH (ONE TO MANY PROBLEM)

# %%
def group_flagged_summary_by_name(df):
    grouped = df.groupby("Name").agg({
        "ID": pd.Series.nunique,
        "Sanction_ID": pd.Series.nunique,  # Keep the first seen sanction ID
        "Type": pd.Series.nunique,         # Keep the first seen type
        "Contracts_Won": "sum",
        "Owns_Companies": "sum",
        "Controls_Companies": "sum",
        "Subsidiary_Links": "sum",
        "Flagged_Links": "sum"
    }).reset_index()

    return grouped

# %%
grouped = group_flagged_summary_by_name(df)
grouped
# Out:
#                   Name  ID  Sanction_ID  Type  Contracts_Won  Owns_Companies  \
# 0    ( Antares CO Ltd)   1            1     1              1               0
# 1            (E)Motion   1            1     1              2               0
# 2           <<Altair>>   1            1     1              2               0
# 3               A-Mig+   1            1     1              1               0
# 4                A-N-O   1            1     1              2               0
# ..                 ...  ..          ...   ...            ...             ...
# 761                htc   1            1     1              2               0
# 762               mira   5            1     1              5               2
# 763                sds   2            1     1              6               0
# 764              smART   1            1     1              1               0
# 765              smart   2            1     1              2               0
#
#      Controls_Companies  Subsidiary_Links  Flagged_Links
# 0                     0                 0              0
# 1                     0                 0              0
# 2                     0                 0              0
# 3                     0                 0              0
# 4                     0                 0              0
# ..                  ...               ...            ...
# 761                   0                 0              0
# 762                   0                 0              0
# 763                   0                 0              0
# 764                   0                 0              0
# 765                   0                 0              0
#
# [766 rows x 9 columns]

# %%
grouped[grouped['ID']>grouped['Sanction_ID']].sort_values('ID')
# Out:
#                 Name    ID  Sanction_ID  Type  Contracts_Won  Owns_Companies  \
# 765            smart     2            1     1              2               0
# 587         SRA & CO     2            1     1              6               0
# 180  DME Company LLC     2            1     1              6               0
# 592         SRA Corp     2            1     1              6               0
# 435        M.O.T INC     2            1     1              2               2
# ..               ...   ...          ...   ...            ...             ...
# 294            Gross   369            1     1            369              91
# 457             Mira   634            1     1            634             301
# 102          Antares  2321            1     1           2321             645
# 636            Smart  3216            1     1           3216             403
# 59            Altair  3995            1     1           7990             928
#
#      Controls_Companies  Subsidiary_Links  Flagged_Links
# 765                   0                 0              0
# 587                   0                 0              0
# 180                   0                 0              0
# 592                   0                 0              0
# 435                   0                 0              0
# ..                  ...               ...            ...
# 294                   1                 0              0
# 457                   3                 0              0
# 102                  22                 0              0
# 636                   6                 0              0
# 59                    8                 0              0
#
# [340 rows x 9 columns]

# %%
def group_orbis_entities_by_name(G):
    """
    Groups Orbis company nodes in the graph by their 'name' attribute.
    
    Returns:
        dict: name → list of node IDs with that name
    """
    from collections import defaultdict

    name_to_ids = defaultdict(list)

    for node, data in G.nodes(data=True):
        if data.get("type") == "Company":
            name = data.get("name", "").strip()
            if name:
                name_to_ids[name].append(node)

    return dict(name_to_ids)

# %%
def map_sanction_ids_to_orbis_ids(G):
    """
    Maps each unique sanction entity ID to a list of matched Orbis company IDs.
    Only considers LegalEntities with a 'flagged_reason' field in the format:
    'Matched to flagged entity <ID>'
    
    Returns:
        dict: sanction_id → list of company node IDs
    """
    import re
    from collections import defaultdict

    sanction_map = defaultdict(list)

    for node, data in G.nodes(data=True):
        if data.get("type") == "Company" and data.get("flagged") == "True":
            reason = data.get("flagged_reason", "")
            match = re.search(r"Matched to flagged entity (\S+)", reason)
            if match:
                sanction_id = match.group(1)
                sanction_map[sanction_id].append(node)

    return dict(sanction_map)

# %%
group_orbis_entities_by_name(Gf)['Altair']
# Out:
# ['RU14282769',
#  'RU19106600',
#  'RU40924122N',
#  'RU36275132',
#  'RU85542139',
#  'RU78403176',
#  'RU67972474',
#  'RU20034231',
#  'RU73515367',
#  'RU26529382',
#  'RU69001148',
#  'RU24147110',
#  'RU89049938',
#  'RU24712461N',
#  'RU89022785',
#  'RU23054493N',
#  'RU72856511N',
#  'RU54225847N',
#  'RU41791396N',
#  'RU71483381',
#  'RU21803811',
#  'RU04416186',
#  'RU95206106',
#  'RU03935777',
#  'RU84209946',
#  'RU45198436N',
#  'RU48935786',
#  'RU90627270',
#  'RU81514873',
#  'RU06601309',
#  'RU33659180',
#  'RU63348678',
#  'RU54178258',
#  'RU53724264N',
#  'RU17298794N',
#  'RU20041705',
#  'RU40567142',
#  'RU98256754',
#  'RU94100268',
#  'RU10627065N',
#  'RU61083856',
#  'RU46275009',
#  'RU97234609',
#  'RU39338985N',
#  'RU39058530N',
#  'RU54309805',
#  'RU77386234',
#  'RU70347892',
#  'RU44551155',
#  'RU54283253',
#  'RU29165176',
#  'RU48962814',
#  'RU92119772',
#  'RU75118044',
#  'RU91609959',
#  'RU19330326',
#  'RU16002751',
#  'RU50455645',
#  'RU69379674',
#  'US263513039L',
#  'RU44310919',
#  'RU05058932',
#  'RU82504167',
#  'RU09910465',
#  'RU71050467',
#  'RU73080705N',
#  'RU18129817N',
#  'MD1015620000911',
#  'RU09360125',
#  'RU96842011',
#  'RU29477533',
#  'RU76121947',
#  'RU62720213',
#  'RU82150290',
#  'RU10310291',
#  'RU52144524N',
#  'RU42241137N',
#  'RU77168945',
#  'RU93898838',
#  'RU59308397',
#  'RU93800325',
#  'RU31798316',
#  'RU11253804',
#  'RU49290498N',
#  'RU33990012',
#  'RU13336397',
#  'RU72359333',
#  'RU*1315721925',
#  'RU72951250',
#  'RU39702928',
#  'RU85273656',
#  'RU64912572',
#  'RU85254216',
#  'RU74125177',
#  'RU06946557',
#  'RU19669906',
#  'RU14298380N',
#  'RU49601768N',
#  'RU74830444',
#  'RU94263970N',
#  'RU70880008',
#  'RU30019238',
#  'RU45909972N',
#  'RU35489078N',
#  'FR400187217',
#  'RU87735167',
#  'RU77742864',
#  'RU42994753',
#  'RU90245343',
#  'RU72727653',
#  'RU71604345',
#  'RU94031780',
#  'RU13079440',
#  'RU05340025',
#  'RU60205857',
#  'RU61947305',
#  'RU01122113',
#  'RU10661783',
#  'RU36818905',
#  'RU16212595',
#  'RU77637156',
#  'RU77458689',
#  'RU13569747',
#  'RU11189236',
#  'RU89911160',
#  'RU93662461',
#  'RU89358208',
#  'RU11181571',
#  'RU87928104',
#  'RU41284541N',
#  'RU11362410',
#  'RU40727841N',
#  'RU93585393',
#  'RU00988023',
#  'RU46890772',
#  'RU90708234',
#  'RU83377707',
#  'RU54037821N',
#  'RU53818930N',
#  'RU49013675N',
#  'RU40357232N',
#  'RU66255121',
#  'RU67780705',
#  'RU65960277',
#  'RU15210068',
#  'RU91749991',
#  'RU86756279',
#  'RU32524489',
#  'RU78163921',
#  'RU82524589',
#  'BE2084784970',
#  'RU31025650',
#  'RU96656646',
#  'RU77459370',
#  'RU*110190578720',
#  'RU46038166',
#  'RU17613830N',
#  'RU82207908',
#  'RU70018119',
#  'RU23371012',
#  'RU89611334',
#  'RU10321805',
#  'YYVS7813602',
#  'RU69840469',
#  'RU83107089',
#  'RU14206917',
#  'RU25357174',
#  'RU43129744',
#  'RU20011112',
#  'RU31332227N',
#  'RU38155248',
#  'RU37718850',
#  'RU45368507N',
#  'RU70513244',
#  'RU42916233N',
#  'RU76851870',
#  'RU84664248',
#  'RU00677257',
#  'RU41547779N',
#  'RU55992269',
#  'RU56839944N',
#  'RU48504135N',
#  'RU82337769N',
#  'RU14442948N',
#  'RU98301420',
#  'RU65961182',
#  'RU58377560N',
#  'RU83609359',
#  'RU*110155565835',
#  'RU67864483',
#  'RU79210054',
#  'RU48745896N',
#  'RU17976588N',
#  'RU38997013N',
#  'RU59413157',
#  'FR889228110',
#  'RU92627327',
#  'RU23354864N',
#  'RU65451765',
#  'RU53629301N',
#  'RU70446200N',
#  'RU43050867',
#  'RU51350374N',
#  'RU45545228',
#  'RU*F0010367115',
#  'RU83892496',
#  'RU09497686',
#  'RU49999564',
#  'RU83387960',
#  'RU79909966',
#  'RU46388937N',
#  'RU66364034',
#  'RU14164892',
#  'RU00494640',
#  'RU76398235',
#  'RU95669036',
#  'RU57934975N',
#  'RU16942046',
#  'RU26188426N',
#  'YYVS7813937',
#  'RU59709047',
#  'RU46458786N',
#  'RU54236130',
#  'RU85028843',
#  'RU65532452',
#  'RU13522059N',
#  'RU16619492N',
#  'RU24106996N',
#  'RU77933512',
#  'RU98677148',
#  'RU96799516',
#  'RU45518254',
#  'RU45557036',
#  'RU57933645N',
#  'RU66481946',
#  'RU69864978',
#  'RU76462335',
#  'RU12731105',
#  'RU78492335',
#  'RU11589013N',
#  'RU53666584',
#  'RU69763289',
#  'RU82217953',
#  'KZ981240008863',
#  'RU15531370',
#  'RU74342236',
#  'RU21546996N',
#  'RU65328846',
#  'UA23262139',
#  'RU53261350',
#  'FR452221641',
#  'RU18965382',
#  'RU42462708N',
#  'RU91447764',
#  'RU29776454N',
#  'RU20900438N',
#  'RU57936773',
#  'RU13850253',
#  'FR818381857',
#  'RU18145762',
#  'RU23370939',
#  'RU25620229',
#  'RU79230074',
#  'RU09162721',
#  'RU16075394',
#  'RU66328251',
#  'BE2088251731',
#  'RU40083088',
#  'RU46286214',
#  'RU26960826',
#  'RU23183012N',
#  'RU01056209',
#  'RU37479457',
#  'RU44890974N',
#  'RU41254391N',
#  'RU60556979',
#  'RU74468960',
#  'RU38009481',
#  'RU22184153',
#  'RU86837061',
#  'RU74614025',
#  'RU11601636N',
#  'RU31680496N',
#  'RU04519897',
#  'RU34379927N',
#  'RU59878525N',
#  'RU01844088',
#  'RU99424610',
#  'RU20123354',
#  'RU12611507N',
#  'RU21269829',
#  'RU96791390',
#  'RU31053906',
#  'RU86827737',
#  'RU50229498',
#  'RU90354434',
#  'RU18855423N',
#  'RU17318670',
#  'RU17250586N',
#  'RU32602539',
#  'RU90320760',
#  'RU15547431',
#  'RU54197022',
#  'RU32036318N',
#  'RU90226179',
#  'RU70007966',
#  'RU44706333',
#  'RU14161008N',
#  'RU93549768',
#  'RU18738746N',
#  'RU03793969',
#  'RU60859243',
#  'RU72776568',
#  'RU98199499',
#  'US141729214L',
#  'RU32998170',
#  'RU92820449',
#  'RU69494406',
#  'RU12091249',
#  'RU36868197',
#  'RU77480737',
#  'RU73937690',
#  'RU63903588',
#  'RU77450624',
#  'RU90425430',
#  'RU78401154',
#  'RU74341260',
#  'RU03869632',
#  'RU33916820',
#  'RU87112443',
#  'RU24231939',
#  'RU97442822',
#  'RU90506803',
#  'RU71992330N',
#  'RU87393719',
#  'RU30018471',
#  'RU25259302',
#  'RU37569864',
#  'RU88783300',
#  'RU93500451',
#  'RU29594090',
#  'RU46043138N',
#  'RU73186225',
#  'RU96525925',
#  'YYVS5012838',
#  'RU94563071',
#  'RU37035275',
#  'RU75564335',
#  'RU78992244',
#  'RU83930357',
#  'RU74037332N',
#  'RU96365568',
#  'RU53831161',
#  'RU34876181',
#  'RU65317245',
#  'RU69524219',
#  'RU31656705',
#  'RU31021102N',
#  'RU72115849',
#  'RU94564944',
#  'RU88988309',
#  'UA*G0020202680',
#  'RU62776099',
#  'RU65864906',
#  'RU80562120',
#  'RU11010786N',
#  'RU03765068',
#  'RU11026830',
#  'RU13842605N',
#  'RU56212754',
#  'RU47712630N',
#  'RU70359792',
#  'RU28266389',
#  'RU24775622',
#  'RU46884406N',
#  'RU54589259N',
#  'RU23140672N',
#  'RU92244023',
#  'RU22158670',
#  'RU60716816',
#  'RU31662255N',
#  'RU31251279N',
#  'RU30675540',
#  'RU44567512',
#  'RU99098814',
#  'RU19469805',
#  'RU58438209N',
#  'RU38912011',
#  'RU86323592',
#  'RU06158848',
#  'RU43166969',
#  'RU61637616',
#  'RU27576550N',
#  'RU31006516',
#  'RU57700496',
#  'RU29932084',
#  'GT33321451119',
#  'RU26671559N',
#  'RU63675271',
#  'RU77421924',
#  'RU05065180',
#  'RU40981700N',
#  'RU31222906',
#  'RU25908189',
#  'RU50071258',
#  'RU15177595',
#  'RU74600649',
#  'RU96260585',
#  'RU65480011',
#  'RU10815677',
#  'RU14196314',
#  'RU95009972',
#  'RU72175107',
#  'RU42191209N',
#  'RU05621876',
#  'RU17120292N',
#  'RU75623078',
#  'RU19010515',
#  'RU43665951',
#  'RU67964351',
#  'RU26217791',
#  'RU27379772',
#  'RU83215620',
#  'RU53788301N',
#  'RU95396696',
#  'RU04209369',
#  'RU40871414N',
#  'RU63070415',
#  'RU77614793',
#  'RU78237192',
#  'RU06669632',
#  'RU62750786',
#  'RU39261069',
#  'RU76086530',
#  'RU77167118',
#  'RU14555782',
#  'RU41763655N',
#  'RU65777001',
#  'RU66221524',
#  'RU64459546',
#  'RU14090113',
#  'RU19906921',
#  'RU32201817',
#  'RU20783211',
#  'RU50138206',
#  'RU00328982',
#  'RU10075097',
#  'RU86630644N',
#  'RU22411873',
#  'RU74717943',
#  'RU38612059',
#  'RU84264201N',
#  'RU09692519',
#  'RU53267217',
#  'RU02994536',
#  'RU70537552',
#  'RU60427667',
#  'RU41150823',
#  'RU84559830',
#  'RU55460668N',
#  'RU30286063',
#  'RU11882316N',
#  'RU41990167N',
#  'RU11361439',
#  'RU88770013',
#  'RU66476997',
#  'RU47245424N',
#  'RU23800461N',
#  'RU98200475',
#  'RU25030798',
#  'RU18640192N',
#  'RU18749550N',
#  'RU16926863N',
#  'RU83398968',
#  'RU32336535N',
#  'RU27994514N',
#  'RU09132602',
#  'RU71509032N',
#  'RU73099035',
#  'RU59547188',
#  'RU09204945',
#  'RU88808603',
#  'RU46975379N',
#  'RU24491215',
#  'RU65977237',
#  'RU13532402N',
#  'RU83568293',
#  'RU29041652',
#  'RU31269210',
#  'RU92776599',
#  'RU12550533N',
#  'RU22224622',
#  'RU83496955',
#  'RU14873826',
#  'RU57037968',
#  'RU67723216',
#  'RU21701066',
#  'RU45739760',
#  'BE0451428595',
#  'RU91017673',
#  'RU48380360',
#  'RU89162209',
#  'RU62667849',
#  'RU66580766',
#  'RU78360231',
#  'FR450327747',
#  'UZ200589875',
#  'RU94664953',
#  'FR530924729',
#  'RU78431244',
#  'RU42459824N',
#  'RU89491887',
#  'RU69488529',
#  'RU92622258',
#  'RU48116657N',
#  'YY*110319513056',
#  'RU93804599',
#  'RU04353534',
#  'RU20090933',
#  'RU04991737',
#  'RU00390567',
#  'RU16098188',
#  'RU65949011',
#  'RU35094641',
#  'RU19684231',
#  'RU83374426',
#  'RU24708985',
#  'RU51768205',
#  'RU72798268',
#  'RU96629045',
#  'RU40399911N',
#  'RU99712830',
#  'RU16773224N',
#  'RU59818405',
#  'RU10163358',
#  'RU89137921',
#  'RU60484560',
#  'RU87676499',
#  'RU96825337',
#  'US116348274GN',
#  'RU78654335',
#  'FR911573897',
#  'RU41402986',
#  'RU82876791',
#  'RU82576103',
#  'RU60558837',
#  'RU62708985',
#  'RU87465124',
#  'RU62584098',
#  'RU48864419',
#  'RU95023831',
#  'RU21060791',
#  'RU03037073',
#  'RU63502547',
#  'RU58337543',
#  'RU65302597',
#  'RU31004285',
#  'RU09525170',
#  'KZ981140006661',
#  'RU43725251',
#  'RU45407644N',
#  'RU54096901N',
#  'RU86707683',
#  'RU83838961',
#  'RU87220049',
#  'RU54209564',
#  'RU46731008',
#  'RU47018183N',
#  'RU58822155',
#  'RU55793051N',
#  'RU64536318',
#  'RU34889261',
#  'RU37981518',
#  'RU62570239',
#  'RU50914395N',
#  'RU69548622',
#  'RU15726228',
#  'RU47609671N',
#  'RU28072936',
#  'RU23854489',
#  'RU20568045',
#  'RU58835436N',
#  'RU40703792',
#  'RU04154208N',
#  'LB0069834561',
#  'RU18988851N',
#  'RU83539162N',
#  'RU21757865',
#  'RU43887048N',
#  'RU20147521',
#  'RU12012913',
#  'RU79082248',
#  'RU59485369',
#  'FR441184173',
#  'RU67899398',
#  'RU95691366',
#  'RU73029069',
#  'RU64412272',
#  'RU28791635',
#  'RU97120120',
#  'RU20735821',
#  'RU70506267',
#  'RU74657342',
#  'RU35400612',
#  'RU41332257',
#  'RU83208726',
#  'RU69832895',
#  'RU94502439',
#  'RU62522708',
#  'RU45554820',
#  'RU64660290',
#  'RU37748041',
#  'RU23169575',
#  'RU69344138',
#  'RU51309360N',
#  'RU06851578',
#  'RU*1316979148',
#  'RU54341163',
#  'RU09057266',
#  'RU48988222N',
#  'RU56169647N',
#  'RU17568064',
#  'RU04652886',
#  'RU06444548',
#  'RU01096108',
#  'RU35010101N',
#  'RU57664174',
#  'RU98751092',
#  'RU04440635',
#  'RU72250777',
#  'RU25293612',
#  'RU17044651N',
#  'RU97875610',
#  'RU83690485N',
#  'RU88823838',
#  'RU72652487',
#  'RU09950341',
#  'RU56554348N',
#  'RU67373621',
#  'RU63032395',
#  'RU90321848',
#  'RU34306029',
#  'RU82335948',
#  'FR517483095',
#  'RU80207270',
#  'RU86689614',
#  'RU43616208',
#  'RU12010015',
#  'RU62799309',
#  'RU63625528',
#  'RU77857704N',
#  'RU14978146',
#  'RU70309532N',
#  'RU45170828N',
#  'RU28033099',
#  'RU83827599',
#  'RU86730340N',
#  'RU02464904',
#  'RU88638259',
#  'RU14356961',
#  'RU12627402',
#  'RU14456896',
#  'RU65729930',
#  'RU68952195',
#  'RU21235345',
#  'RU59516093',
#  'RU99797208',
#  'RU87010895',
#  'RU55872945N',
#  'RU93714287',
#  'RU17184205N',
#  'RU60948299',
#  'RU42775426N',
#  'RU83681144',
#  'RU49560963N',
#  'RU71943225',
#  'RU25465958',
#  'RU06576505',
#  'RU15854529',
#  'RU63689238',
#  'RU21976774',
#  'RU96843157',
#  'RU29170438',
#  'RU91069078',
#  'RU*607000422',
#  'RU35996361',
#  'RU70979882',
#  'RU09124933',
#  'RU30762233',
#  'RU45668072N',
#  'RU15020770',
#  'RU70298874',
#  'RU83558030',
#  'RU77223748',
#  'RU23516901',
#  'RU95554712',
#  'RU31756795N',
#  'RU23054375',
#  'RU01186834',
#  'RU70251229',
#  'RU02150749',
#  'RU83730434',
#  'RU85922853',
#  'RU15208580',
#  'RU18045724N',
#  'RU88760049',
#  'RU45586977N',
#  'RU99362659',
#  'RU45408879N',
#  'RU32731774',
#  'RU98259190',
#  'RU41056900',
#  'RU34590579N',
#  'RU25562756',
#  'RU27647267',
#  'RU53301799',
#  'RU25962792',
#  'RU50877435',
#  'RU39421114N',
#  'RU09565235',
#  'RU41263556',
#  'RU33961281',
#  'RU78411684',
#  'RU54356164',
#  'RU00058169',
#  'RU13839974N',
#  'RU70660301',
#  'RU70269424',
#  'RU25013417',
#  'RU03348488',
#  'RU74409957',
#  'RU14091928',
#  'RU28307970',
#  'RU64337056',
#  'RU01724131',
#  'RU51572910',
#  'RU88751406',
#  'RU78379970N',
#  'RU93739666',
#  'RU14501177N',
#  'RU35909190',
#  'RU45493553N',
#  'RU56182183',
#  'RU36218393N',
#  'RU80679684',
#  'RU44261664N',
#  'RU39076700',
#  'RU16055776',
#  'RU31085562N',
#  'RU19890485',
#  'RU42345291',
#  'RU00895132',
#  'RU60340966',
#  'RU80464216',
#  'RU34320377N',
#  'RU42952223N',
#  'RU20834204N',
#  'RU25184610',
#  'RU50894633',
#  'RU97821212N',
#  'RU73436544',
#  'KZ941240000916',
#  'RU42462861N',
#  'RU92456363',
#  'RU13090832',
#  'RU68572191',
#  'RU86458487',
#  'RU73106344',
#  'RU43002624N',
#  'RU90112056',
#  'RU45572509N',
#  'RU56142462',
#  'RU14574650',
#  'RU19511523',
#  'RU80721937N',
#  'US161554263L',
#  'RU23294435N',
#  'RU15953852',
#  'RU24225198N',
#  'RU96442211',
#  'US161931846L',
#  'RU73363710',
#  'RU60997656',
#  'RU32488629N',
#  'RU15398250',
#  'RU83072008',
#  'RU26404214',
#  'RU75344875',
#  'RU40867335',
#  'RU82210388',
#  'RU81455024',
#  'RU35010704',
#  'RU61340626',
#  'RU64482338',
#  'RU14387638',
#  'RU54071216',
#  'RU97257817',
#  'RU71242333N',
#  'YYVS2598881',
#  'RU33108066',
#  'RU56324370',
#  'RU93083119N',
#  'RU12284994',
#  'RU79252093',
#  'RU38834452',
#  'RU42652254',
#  'RU86743377',
#  'RU97340323',
#  'RU27469185',
#  'RU64246017',
#  'RU60691401',
#  'RU10965632',
#  'RU27739325',
#  'RU54629846',
#  'RU93469965',
#  'RU11491745',
#  'RU50889605N',
#  'RU10277331',
#  'RU74515918',
#  'RU13987953',
#  'RU13244028',
#  'RU37246871',
#  'RU64918528',
#  'RU17310319N',
#  'YYVS8858776',
#  'RU61118810',
#  'RU03859349',
#  'RU33095783',
#  'RU39618978N',
#  'RU09579467',
#  'RU75376450',
#  'RU30959444',
#  'RU86296286',
#  'RU70965029',
#  'RU83379184',
#  'RU03794503',
#  'RU69220488',
#  'RU34465360',
#  'RU35133358',
#  'RU46286094N',
#  'RU24157108N',
#  'RU14884132N',
#  'RU76413928',
#  'RU98370941',
#  'RU65818869',
#  'RU56193436',
#  'RU44740442',
#  'RU95550631',
#  'RU20513150',
#  'RU12007757',
#  'RU60014787',
#  'RU20515060N',
#  'RU89761795',
#  'RU35599312',
#  'RU49733553N',
#  'YYVS4644799',
#  'RU20482047',
#  'RU75125707N',
#  'RU98396219',
#  'RU17917352N',
#  'RU23874457',
#  'RU93082195',
#  'RU96562091',
#  'RU79754297',
#  'RU85237815',
#  'RU70474931',
#  'RU34670798',
#  'RU15864752',
#  'RU33826643',
#  'RU05835991',
#  'RU26207106N',
#  'RU94511706',
#  'RU12775829N',
#  'RU10993611N',
#  'RU05426270',
#  'RU13641344',
#  'RU29854131N',
#  'RU16749409',
#  'UA193119284',
#  'RU79792553',
#  'RU79456987',
#  'RU22264320',
#  'RU09787970',
#  'RU10149157',
#  'RU58811111',
#  'RU70880095',
#  'RU62639505',
#  'RU95169245',
#  'RU10367747',
#  'RU85217422',
#  'RU92163193',
#  'RU04994019',
#  'RU53299134',
#  'RU42932611N',
#  'RU24100099',
#  'RU64580791',
#  'RU10530302',
#  'RU79584866',
#  'RU81419844',
#  'RU66968424',
#  'RU87618042',
#  'RU31039510N',
#  'RU29379368',
#  'RU77675381',
#  'RU95366962',
#  'RU30047364',
#  'RU40111956N',
#  'RU06713333',
#  'RU92622241',
#  'ME02343878',
#  'RU79612019',
#  'RU95148426',
#  'RU30743827',
#  'RU80753140',
#  'RU70507924',
#  'RU43354211',
#  'RU77594961',
#  'RU52959835N',
#  'RU80838881',
#  'RU14136571',
#  'RU20704795',
#  'RU59538338',
#  'RU17618891',
#  'RU73709060',
#  'RU56722047N',
#  'RU85303222',
#  'RU48974177',
#  'RU26014424',
#  'RU01125270',
#  'RU76137196',
#  'RU33187215',
#  'RU33993513',
#  'RU86284254',
#  'RU71214182',
#  'RU03304507',
#  'RU38435969',
#  'RU97432947',
#  'RU69266527',
#  'RU50270319',
#  'RU11174849',
#  'RU19149395',
#  'RU42090388',
#  'RU83798604',
#  'RU80525308',
#  'RU92765590',
#  'RU93106493',
#  'RU49674885',
#  'RU23777820',
#  'RU75318168',
#  'RU33166514',
#  'RU54181895',
#  'RU22680260',
#  'RU03924041',
#  'RU50274754N',
#  'RU38211952',
#  'RU71373555',
#  'RU75179117',
#  'RU27216283',
#  'RU34405116N',
#  'RU82723283',
#  'RU18449284N',
#  'RU26955050N',
#  'RU36297116N',
#  'RU85076051',
#  'RU40300723N',
#  'RU76955701',
#  'RU21856691',
#  'RU44601835',
#  'RU22838442',
#  'RU14060224',
#  'RU97532657',
#  'RU82226573',
#  'RU90690793',
#  'RU22024998',
#  'RU75342155N',
#  'RU48134325',
#  'RU40071524N',
#  'RU26710360',
#  'RU20091045',
#  'RU03450910',
#  'RU94387666',
#  'RU18089503',
#  'RU11663614N',
#  'RU37502073',
#  'RU68544912',
#  'RU24839760N',
#  'RU61973604',
#  'RU04484756',
#  'RU59892620N',
#  'RU72280850N',
#  'RU20096054',
#  'RU87072519',
#  'RU13857423',
#  'RU71335224',
#  'RU72805488',
#  'RU48906023',
#  'RU38920223',
#  'RU92914363',
#  'RU00360218',
#  'RU91060226',
#  ...]

# %% [markdown]
# #### GRAPH PRUNING

# %%
def clean_node_attributes(G):
    """
    Ensures all node attributes are stored as strings and missing values are handled.
    """
    for node in G.nodes:
        for attr, value in G.nodes[node].items():
            if pd.isna(value) or value is None:  # Replace NaN/None with 'Unknown'
                G.nodes[node][attr] = "Unknown"
            else:
                G.nodes[node][attr] = str(value)  # Convert everything to a string

def save_graph(G, country_code):
    """
    Saves the graph to GraphML format.
    """
    clean_node_attributes(G)  # Ensure consistent types before saving
    nx.write_graphml(G, f"procurement_graph_{country_code}_clean.graphml")
    print(f"✅ Graph saved to procurement_graph_{country_code}_clean.graphml")

# %%
import networkx as nx
from collections import defaultdict, deque
import copy

def label_and_clean_matched_companies_create_new(G):
    """
    Creates a cleaned copy of the graph with company nodes labeled by match confidence,
    removes 'SuperLow' confidence matches, and recursively removes disconnected Orbis nodes.
    """
    G_cleaned = copy.deepcopy(G)

    # Step 1: Group company nodes by name
    name_to_nodes = defaultdict(list)
    name_to_unique_ids = defaultdict(set)

    for node, data in G.nodes(data=True):
        if data.get("type") == "Company" and data.get("bid_winner") == "True":
            name = data.get("name")
            national_id = data.get("win_nationalid")
            name_to_nodes[name].append(node)
            if national_id:
                name_to_unique_ids[name].add(national_id)

    # Step 2: Label confidence
    last_win_country = None
    superlow_nodes = set()
    for name, nodes in name_to_nodes.items():
        expected_matches = len(name_to_unique_ids[name])
        for node in nodes:
            data = G_cleaned.nodes[node]
            bvd_country = str(data.get("bvdidnumber", ""))[:2].upper()
            win_country = str(data.get("win_country_code", ""))[:2].upper()
            last_win_country = win_country

            country_match = bvd_country == win_country
            total_matches = len(nodes)

            # Determine confidence
            if country_match and total_matches == 1:
                confidence = "Very High"
            elif country_match and total_matches <= expected_matches:
                confidence = "High"
            elif not country_match and total_matches <= expected_matches:
                confidence = "Medium"
            elif country_match and total_matches >= expected_matches:
                confidence = "Low"
            else:
                confidence = "SuperLow"

            data["match_confidence"] = confidence

            if confidence == "SuperLow":
                superlow_nodes.add(node)

    # Step 3: Remove all SuperLow nodes and clean neighbors
    print(f"🧹 Removing {len(superlow_nodes)} SuperLow nodes and cleaning neighbors...")
    G_cleaned.remove_nodes_from(superlow_nodes)

    # Step 4: Keep only nodes reachable from procurement
    reachable = set()
    for node, data in G_cleaned.nodes(data=True):
        if data.get("type") == "Procurement":
            queue = deque([node])
            visited = set()
            while queue:
                current = queue.popleft()
                if current in visited:
                    continue
                visited.add(current)
                reachable.add(current)
                neighbors = set(G_cleaned.successors(current)).union(G_cleaned.predecessors(current))
                queue.extend(neighbors - visited)

    all_nodes = set(G_cleaned.nodes())
    unreachable_nodes = all_nodes - reachable
    G_cleaned.remove_nodes_from(unreachable_nodes)

    # Step 5: Remove final orphans
    orphans = [n for n in G_cleaned.nodes if G_cleaned.degree(n) == 0]
    G_cleaned.remove_nodes_from(orphans)

    save_graph(G_cleaned, last_win_country)
    print(f"✅ Cleaned graph created. Removed {len(superlow_nodes)} SuperLow nodes and {len(unreachable_nodes)} unreachable nodes.")
    return G_cleaned

# %%
Gf_clean = label_and_clean_matched_companies_create_new(Gf)
# Out:
# 🧹 Removing 697485 SuperLow nodes and cleaning neighbors...
# ✅ Graph saved to procurement_graph_FR_clean.graphml
# ✅ Cleaned graph created. Removed 697485 SuperLow nodes and 116091 unreachable nodes.

# %% [markdown]
# #### INTEGRITY

# %%
def check_graph_integrity(G):
    """
    Checks if the graph meets integrity expectations:
    - No orphan nodes (nodes with no edges)
    - Only isolated pairs are connected by 'WON' edges
    - Each procurement node has only one incoming 'WON' edge
    """
    print("🧪 Running graph integrity checks...")

    # 1. Orphan nodes
    orphan_nodes = [n for n in G.nodes if G.degree(n) == 0]
    if orphan_nodes:
        print(f"❌ Found {len(orphan_nodes)} orphan nodes.")
    else:
        print("✅ No orphan nodes found.")

    # 2. Isolated pairs must be connected only by 'WON' edges
    only_one_edge = []
    for u, v in G.edges:
        if G.degree(u) == 1 and G.degree(v) == 1:
            rel = G.edges[u, v].get("relationship")
            if rel != "WON":
                only_one_edge.append((u, v, rel))

    if only_one_edge:
        print(f"❌ Found {len(only_one_edge)} node pairs connected only by non-WON edges.")
        for u, v, rel in only_one_edge[:5]:  # Show a few examples
            print(f"   - ({u}, {v}) via {rel}")
    else:
        print("✅ All isolated pairs are connected by 'WON' edges only.")

    # 3. Each Procurement node should have at most one incoming 'WON' edge
    bad_procurements = []
    for node, data in G.nodes(data=True):
        if data.get("type") == "Procurement":
            won_in_edges = [
                (u, v) for u, v in G.in_edges(node)
                if G.edges[u, v].get("relationship") == "WON"
            ]
            if len(won_in_edges) > 1:
                bad_procurements.append((node, len(won_in_edges)))

    if bad_procurements:
        print(f"❌ Found {len(bad_procurements)} procurement nodes with multiple 'WON' edges.")
        for pid, count in bad_procurements[:5]:
            print(f"   - Procurement {pid} has {count} winners.")
    else:
        print("✅ All procurements have at most one winning company.")

    print("🧪 Integrity check complete.\n")

# %%
check_graph_integrity(Gf_clean)
# Out:
# 🧪 Running graph integrity checks...
# ✅ No orphan nodes found.
# ✅ All isolated pairs are connected by 'WON' edges only.
# ✅ All procurements have at most one winning company.
# 🧪 Integrity check complete.

# %%
summarize_graph(Gf)
# Out:
# ===== Graph Summary =====
# Total Nodes: 2469037
# Total Edges: 1651874
#
# Node Types:
#   - Company: 1150169
#   - Procurement: 1318863
#   - Flagged: 5
#
# Edge Types:
#   - WON: 1318863
#   - CONTROLS: 34460
#   - OWNS: 298340
#   - SUBSIDIARY_OF: 122
#   - FLAGGED_LINK: 89
#
# Flagged Companies: 14078
# =========================

# %%
summarize_graph(Gf_clean)
# Out:
# ===== Graph Summary =====
# Total Nodes: 606730
# Total Edges: 431038
#
# Node Types:
#   - Procurement: 270132
#   - Company: 336594
#   - Flagged: 4
#
# Edge Types:
#   - WON: 270132
#   - CONTROLS: 12973
#   - OWNS: 147819
#   - FLAGGED_LINK: 37
#   - SUBSIDIARY_OF: 77
#
# Flagged Companies: 659
# =========================

# %%
summarize_flagged_entity_relations_separately(Gf_clean)
# Out:
# ===== FLAGGED ENTITY RELATION SUMMARY (by type) =====
# Scanning nodes: 100%|██████████| 606730/606730 [00:00<00:00, 956586.19node/s]
# Scanning edges: 100%|██████████| 431038/431038 [00:00<00:00, 1172791.11edge/s]
# Flagged Companies Total: 659
# Flagged People Total: 4
#
# Flagged Companies with WON edges: 644
# Flagged Companies with OWNS edges: 201
# Flagged Companies with CONTROLS edges: 27
# Flagged Companies with SUBSIDIARY_OF edges: 0
# Flagged People with FLAGGED_LINK connections: 4
#
# Top 10 by Contracts Won:
#                Name              ID  Contracts Won
#             SAS SRA     FR839969888              3
#              S.R.A.     FR525157004              3
# SDS Company Co.,Ltd KR1357110170177              3
#                 SDS     FR444819726              3
#                 SDS     FR801130105              3
#        D-M-E CO INC    US191783640L              3
#               S.D.S     FR432553139              3
#            DME Llc,    US317049218L              3
#         SDS LTD INC    US135683443L              3
#            SDS Co.,    US316895450L              3
#
# Top 10 by Companies Owned:
#              Name              ID  Companies Owned
#             Smart     FR848990743               18
#            Altair     FR434178471                7
#               HTC     FR389044140                7
#               ECI     FR528511249                4
#              Mira     FR493450589                4
#              Mira     FR849286208                4
#            Altair     FR421507773                4
# D-M-E Company INC    US303519434L                4
#            E.C.I.     FR344915095                4
#      E-Ta Co.,Ltd KR1543110015104                3
#
# Top 10 by Companies Controlled:
#                Name              ID  Companies Controlled
#              Tradex     FR334314671                     1
#                 NCG     FR433112570                     1
#             Al'Tair  UA*G0014086815                     1
#               Symed     FR450183124                     1
#            FSM Corp    US240372395L                     1
#                 SDS     FR382580652                     1
#             STC SAS FR*110331319211                     1
#                 ACE     FR478123185                     1
# Antares Company LLC    US343014974L                     1
#             Antares     FR422831859                     1
#
# Top 10 by Subsidiary Links:
# Empty DataFrame
# Columns: []
# Index: []
#
# Top 10 by Linked Companies:
#          Name                                                ID  Linked Companies
#   THOMAS COOK us-medme-4473a0acda59c8a67f703878f6dab12e1d312cab                20
#       ACHILLE                                   usgsa-s4mr3pzb3                15
# CARLOS MEDINA        us-fed-excl-carlos-medina-36112-montgomery                 1
#  MARIE GILLES      us-fed-excl-marie-gilles-10507-bedford-hills                 1
#
# ===== END OF SUMMARY =====

# %%
summarize_flagged_entity_relations_separately(Gf)
# Out:
# ===== FLAGGED ENTITY RELATION SUMMARY (by type) =====
# Scanning nodes: 100%|██████████| 2469037/2469037 [00:02<00:00, 1069279.94node/s]
# Scanning edges: 100%|██████████| 1651874/1651874 [00:01<00:00, 1134385.37edge/s]
# Flagged Companies Total: 14078
# Flagged People Total: 5
#
# Flagged Companies with WON edges: 14032
# Flagged Companies with OWNS edges: 2440
# Flagged Companies with CONTROLS edges: 152
# Flagged Companies with SUBSIDIARY_OF edges: 0
# Flagged People with FLAGGED_LINK connections: 5
#
# Top 10 by Contracts Won:
#        Name              ID  Contracts Won
#         SDS      RU33409052              3
#         SDS      NL57100411              3
#         SDS    US149304995L              3
#         SDS    US127065902L              3
#      S.D.S.    BE2065908374              3
#         DME      RU33970469              3
#         SDS     RU43732104N              3
# SDS Co.,Ltd KR1201110656720              3
#         SDS      RU50909810              3
#     SDS LLC    US266102738L              3
#
# Top 10 by Companies Owned:
#    Name              ID  Companies Owned
#    Mira     BG836144081               22
#  Altair      RU05368064               20
#   Smart     FR848990743               18
#  Altair   IT02301900060                8
#  Altair     RU44890974N                7
#  Altair     FR434178471                7
#     HTC     FR389044140                7
#    Mira      RU60851454                6
# ECI INC JP4020001092353                6
# Antares      RU71440317                6
#
# Top 10 by Companies Controlled:
#            Name            ID  Companies Controlled
#             SDS  US127065902L                     1
# Advance Medical  US226667102L                     1
#             ECI  US201999336L                     1
#         Antares   RU98413308N                     1
#       Narrative USND-28397100                     1
#         ECI INC  US186097497L                     1
#        Smart CO  US144159439L                     1
#             CEC  US161580657L                     1
#      Sunset INC  US254938286L                     1
#             CEC  US162560439L                     1
#
# Top 10 by Subsidiary Links:
# Empty DataFrame
# Columns: []
# Index: []
#
# Top 10 by Linked Companies:
#            Name                                                ID  Linked Companies
#     THOMAS COOK us-medme-4473a0acda59c8a67f703878f6dab12e1d312cab                53
#         ACHILLE                                   usgsa-s4mr3pzb3                20
#   CARLOS MEDINA        us-fed-excl-carlos-medina-36112-montgomery                 9
# CATHERINE JONES          us-fed-excl-catherine-jones-39940-laurel                 6
#    MARIE GILLES      us-fed-excl-marie-gilles-10507-bedford-hills                 1
#
# ===== END OF SUMMARY =====

# %% [markdown]
# #### WORK ON SANCTIONS

# %%
df = summarize_flagged_entities_to_csv(Gf_clean)
# Out:
# ✅ Summary saved to flagged_entity_summary.csv

# %%
grouped = group_flagged_summary_by_name(df)

# %%
grouped[grouped['ID']>grouped['Sanction_ID']].sort_values('ID')
# Out:
#              Name  ID  Sanction_ID  Type  Contracts_Won  Owns_Companies  \
# 263       Novacom   2            1     1              2               1
# 322           SRA   2            1     1              6               1
# 212  Interconsult   2            1     1              2               0
# 392         Symed   2            1     1              2               4
# 287         S.D.S   2            1     1              6               0
# 141          Erys   2            1     1              2               0
# 288        S.D.S.   2            1     1              6               0
# 109      E-Motion   3            1     1              6               1
# 130           ETA   3            1     1              6               3
# 299        S.T.C.   4            1     1              4               0
# 120         E.C.I   4            1     1              4               1
# 121        E.C.I.   4            1     1              4               6
# 178           HTC   5            1     1             10              11
# 10            AFG   5            1     1              5               1
# 95            DME   7            1     1             21               5
# 134       Emotion   7            1     1             14               3
# 79            CEC   8            1     1              8               8
# 128           ECI   9            1     1              9               6
# 404        Tradex  10            1     1             20              11
# 379        Sunset  11            1     1             22               6
# 150           FSM  12            1     1             24               5
# 346         Smart  12            1     1             12              24
# 277           PCI  12            1     1             12               7
# 194           ICI  12            1     1             24              11
# 246          Mira  19            1     1             19              12
# 307           SDS  19            1     1             57              15
# 329           STC  19            1     1             19              12
# 55        Antares  33            1     1             33              36
# 35         Altair  38            1     1             76              41
#
#      Controls_Companies  Subsidiary_Links  Flagged_Links
# 263                   0                 0              0
# 322                   0                 0              0
# 212                   0                 0              0
# 392                   1                 0              0
# 287                   0                 0              0
# 141                   0                 0              0
# 288                   0                 0              0
# 109                   0                 0              0
# 130                   0                 0              0
# 299                   0                 0              0
# 120                   0                 0              0
# 121                   0                 0              0
# 178                   0                 0              0
# 10                    0                 0              0
# 95                    0                 0              0
# 134                   0                 0              0
# 79                    0                 0              0
# 128                   0                 0              0
# 404                   1                 0              0
# 379                   2                 0              0
# 150                   0                 0              0
# 346                   0                 0              0
# 277                   1                 0              0
# 194                   0                 0              0
# 246                   0                 0              0
# 307                   1                 0              0
# 329                   0                 0              0
# 55                    4                 0              0
# 35                    2                 0              0

# %%
def check_for_superlow_winners(G):
    """
    Checks whether any procurement-winning companies still have 'SuperLow' match_confidence.
    Returns a list of such nodes and prints a summary.
    """
    superlow_nodes = []

    for node, data in G.nodes(data=True):
        if data.get("type") == "Company" and data.get("bid_winner") == "True":
            if data.get("match_confidence") == "SuperLow":
                superlow_nodes.append((node, data.get("name", "Unknown")))

    print(f"❗ Found {len(superlow_nodes)} procurement winners with 'SuperLow' confidence.")
    if superlow_nodes:
        print("🔍 Sample:")
        for node, name in superlow_nodes[:10]:
            print(f"  - Node ID: {node}, Name: {name}")

    return superlow_nodes

# %%
check_for_superlow_winners(Gf_clean)
# Out:
# ❗ Found 0 procurement winners with 'SuperLow' confidence.
# []

# %%
sanctions = pd.read_csv('/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/data/Black_Lists/Black_Lists_Data_Sets/open_sanctions.csv')
# Out:
# /var/folders/r2/9vnxdxyd26380tms_8k538b40000gn/T/ipykernel_27921/1351478014.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sanctions = pd.read_csv('/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/data/Black_Lists/Black_Lists_Data_Sets/open_sanctions.csv')

# %%
sanctions.groupby('name').count()
# Out:
#                                                     id  schema  aliases  \
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...   1       1        0
# "ABU AL-HASAN AL MADANI"                             2       2        1
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...   1       1        1
# "AHMED THE TANZANIAN"                                1       1        1
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...   1       1        1
# ...                                                 ..     ...      ...
# Željko Milovanović, s.p., poslovno svetovanje i...   1       1        0
# “AGIDEL-AS” LLP                                      2       2        0
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati      1       1        1
# “TIMIR” LLP                                          1       1        0
# “Timir” LLP (“Timir”)                                1       1        0
#
#                                                     birth_date  countries  \
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...           0          1
# "ABU AL-HASAN AL MADANI"                                     0          0
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...           0          0
# "AHMED THE TANZANIAN"                                        0          0
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...           0          0
# ...                                                        ...        ...
# Željko Milovanović, s.p., poslovno svetovanje i...           0          1
# “AGIDEL-AS” LLP                                              0          2
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati              0          1
# “TIMIR” LLP                                                  0          1
# “Timir” LLP (“Timir”)                                        0          1
#
#                                                     addresses  identifiers  \
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...          0            1
# "ABU AL-HASAN AL MADANI"                                    0            0
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...          0            1
# "AHMED THE TANZANIAN"                                       0            0
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...          0            1
# ...                                                       ...          ...
# Željko Milovanović, s.p., poslovno svetovanje i...          0            1
# “AGIDEL-AS” LLP                                             1            0
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati             1            0
# “TIMIR” LLP                                                 1            0
# “Timir” LLP (“Timir”)                                       0            0
#
#                                                     sanctions  phones  emails  \
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...          0       0       0
# "ABU AL-HASAN AL MADANI"                                    2       0       0
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...          1       0       0
# "AHMED THE TANZANIAN"                                       1       0       0
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...          1       0       0
# ...                                                       ...     ...     ...
# Željko Milovanović, s.p., poslovno svetovanje i...          0       0       0
# “AGIDEL-AS” LLP                                             2       0       0
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati             1       0       0
# “TIMIR” LLP                                                 1       0       0
# “Timir” LLP (“Timir”)                                       1       0       0
#
#                                                     dataset  first_seen  \
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...        1           1
# "ABU AL-HASAN AL MADANI"                                  2           2
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...        1           1
# "AHMED THE TANZANIAN"                                     1           1
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...        1           1
# ...                                                     ...         ...
# Željko Milovanović, s.p., poslovno svetovanje i...        1           1
# “AGIDEL-AS” LLP                                           2           2
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati           1           1
# “TIMIR” LLP                                               1           1
# “Timir” LLP (“Timir”)                                     1           1
#
#                                                     last_seen  last_change
# name
# " KLJUČAVNIČARSTVO ",SERVISIRANJE IN MONTAŽA MI...          1            1
# "ABU AL-HASAN AL MADANI"                                    2            2
# "AGRICOLA RUELAS", SOCIEDAD DE PRODUCCION RURAL...          1            1
# "AHMED THE TANZANIAN"                                       1            1
# "ALONDRA PRODUCE", SOCIEDAD DE PRODUCCION RURAL...          1            1
# ...                                                       ...          ...
# Željko Milovanović, s.p., poslovno svetovanje i...          1            1
# “AGIDEL-AS” LLP                                             2            2
# “Interyer Insaat” Mahdud Masuliyyatli Cəmiyyati             1            1
# “TIMIR” LLP                                                 1            1
# “Timir” LLP (“Timir”)                                       1            1
#
# [200971 rows x 14 columns]

# %%
sanctions[sanctions['id']=='NK-Gbik6Hp3G8o9nPkMzyq68M']
# Out:
#                              id       schema         name  \
# 8280  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
#
#                                             aliases birth_date countries  \
# 8280  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
#
#                                               addresses  \
# 8280  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
#
#                                  identifiers                sanctions  phones  \
# 8280  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
#
#       emails                        dataset           first_seen  \
# 8280     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
#
#                 last_seen          last_change
# 8280  2025-01-07T07:55:02  2024-12-03T11:56:57

# %%
sanctions
# Out:
#                                id       schema  \
# 0       NK-22HtK7WrxZ2sU3rmhz6PuZ       Person
# 1       NK-22JRrAHhpxzN8wN5pP6EGo       Person
# 2       NK-22MHXvQQufBgTjUWgUbWb8  LegalEntity
# 3       NK-22T6dTsc6umYgEA33vME3t  LegalEntity
# 4       NK-22cQD3a8GDRSuoW5mus3F3  LegalEntity
# ...                           ...          ...
# 205983               wbdeb-888293  LegalEntity
# 205984               wbdeb-888338  LegalEntity
# 205985               wbdeb-895566  LegalEntity
# 205986               wbdeb-927832  LegalEntity
# 205987               wbdeb-927833  LegalEntity
#
#                                                      name  \
# 0                                         MICHAEL KUAJIEN
# 1                                         YASIN M HUSSAIN
# 2       LIMITED LIABILITY COMPANY SPECIALIZED DEVELOPE...
# 3                         DIGITAL MARKETING AWARDS FZ LLC
# 4                         EKVIK LIMITED LIABILITY COMPANY
# ...                                                   ...
# 205983  HEBEI CONSTRUCTION GROUP CORPORATION LIMITED Q...
# 205984  HEBEI CONSTRUCTION GROUP CORPORATION LIMITED M...
# 205985      SINO-KENYA ENGINEERING GROUP COMNPANY LIMITED
# 205986                                  MR. RUFAT MAJIDOV
# 205987                                   GRAND MOTORS LLC
#
#                                                   aliases  birth_date  \
# 0              MICHAEL KUAJIAN;MICHAEL KUAJIEN DUER MAYOK         NaN
# 1                                        Yasin M. Hussain  1965-01-19
# 2            LLC SPECIALIZED DEVELOPER ALABUGA SOUTH PARK         NaN
# 3       SWISS DRAGONS MANAGEMENT DIGITAL MARKETING AWARDS         NaN
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 205983                                                NaN         NaN
# 205984                                                NaN         NaN
# 205985                                                NaN         NaN
# 205986                                                NaN         NaN
# 205987                                                NaN         NaN
#
#        countries                                          addresses  \
# 0             ke                                       NAIROBI, KEN
# 1             us  11646 SUN CIRCLE WAY, COLUMBIA, MD 21044;11646...
# 2             ru  UL. SH-2 (OEZ ALABUGA TER.), D. 15/5, POMESHCH...
# 3             ae  COMPASS BUILDING FDRK 2508, AL SHOHADA ROAD, A...
# 4             ru  PER. DUKHOVSKOI D. 17, KORPUS 1, FLOOR 1 PODYE...
# ...          ...                                                ...
# 205983        cn  NO. 382,WEST DEVELOPMENT ROAD, QINGYUAN DISTRI...
# 205984        cn  NO 859, XIANGYANG SOUTH STREET, JINGXIU DISTRI...
# 205985        ke  NEXTGEN APARTMENTS, BLOCK B, HOUSE NO. 41, MOM...
# 205986        az  BINAGADI HIGHWAY, MADAN STREET 4 AZ1053, BAKU,...
# 205987        az  BINAGADI HIGHWAY, MADAN STREET 4 AZ1053, BAKU,...
#
#                       identifiers  \
# 0                             NaN
# 1                             NaN
# 2       C526RHBSEVC3;U1EZWUPPYNN3
# 3       EVSNP8SMGZF5;PCEXVGTXWFB4
# 4                    Y6MSPLJPJ9J5
# ...                           ...
# 205983                        NaN
# 205984                        NaN
# 205985                        NaN
# 205986                        NaN
# 205987                        NaN
#
#                                                 sanctions  phones  emails  \
# 0                                 Reciprocal - 2019-12-10     NaN     NaN
# 1       1996-06-10;US HHS OIG List of Excluded Individ...     NaN     NaN
# 2                                 Reciprocal - 2024-02-23     NaN     NaN
# 3                                 Reciprocal - 2024-08-23     NaN     NaN
# 4                                 Reciprocal - 2024-10-30     NaN     NaN
# ...                                                   ...     ...     ...
# 205983     Cross Debarment: ADB - 2024-08-22 - 2027-07-22     NaN     NaN
# 205984     Cross Debarment: ADB - 2024-08-22 - 2027-07-22     NaN     NaN
# 205985    Cross Debarment: AfDB - 2021-10-18 - 2999-12-31     NaN     NaN
# 205986    Obstructive Practices - 2024-12-10 - 2027-08-09     NaN     NaN
# 205987    Obstructive practices - 2024-12-10 - 2027-08-09     NaN     NaN
#
#                                                   dataset  \
# 0                           US SAM Procurement Exclusions
# 1       US Health and Human Sciences Inspector General...
# 2                           US SAM Procurement Exclusions
# 3                           US SAM Procurement Exclusions
# 4                           US SAM Procurement Exclusions
# ...                                                   ...
# 205983                       WorldBank Debarred Providers
# 205984                       WorldBank Debarred Providers
# 205985                       WorldBank Debarred Providers
# 205986                       WorldBank Debarred Providers
# 205987                       WorldBank Debarred Providers
#
#                  first_seen            last_seen          last_change
# 0       2024-06-14T06:55:20  2025-01-07T07:55:02  2024-09-10T07:55:01
# 1       2024-05-08T21:57:02  2025-01-07T07:43:04  2024-10-15T07:43:06
# 2       2024-06-14T06:55:20  2025-01-07T07:55:02  2024-12-03T11:56:57
# 3       2024-09-21T07:55:17  2025-01-07T07:55:02  2024-12-03T11:56:57
# 4       2024-11-01T07:55:06  2025-01-07T07:55:02  2024-12-03T11:56:57
# ...                     ...                  ...                  ...
# 205983  2024-08-23T15:03:03  2025-01-07T15:03:01  2024-11-28T15:03:03
# 205984  2024-08-23T15:03:03  2025-01-07T15:03:01  2024-11-28T15:03:03
# 205985  2024-09-17T15:03:04  2025-01-07T15:03:01  2024-11-28T15:03:03
# 205986  2024-12-11T15:03:02  2025-01-07T15:03:01  2024-12-11T15:03:02
# 205987  2024-12-11T15:03:02  2025-01-07T15:03:01  2024-12-11T15:03:02
#
# [205988 rows x 15 columns]

# %%
# Group by 'name' and count all columns
grouped_counts = sanctions.groupby('name').count()

# Filter to keep only rows where the count of 'id' is greater than 1
result = grouped_counts[grouped_counts['id'] > 4]
result
# Out:
#                                               id  schema  aliases  birth_date  \
# name
# AL-AQSA ASBL                                   8       8        8           0
# AL-AQSA CHARITABLE FOUNDATION                  9       9        9           0
# AL-AQSA CHARITABLE ORGANIZATION                9       9        9           0
# AL-AQSA E.V.                                   9       9        9           0
# AL-AQSA FOUNDATION                             9       9        9           0
# AL-AQSA INTERNATIONAL FOUNDATION               9       9        9           0
# AL-AQSA ISLAMIC CHARITABLE SOCIETY             9       9        9           0
# AL-AQSA SINABIL ESTABLISHMENT                  9       9        9           0
# AL-AQSA SPANM I STIFTELSE                      9       9        9           0
# AL-AQSA SPANMAL STIFTELSE                      9       9        9           0
# AL-HARAMAIN FOUNDATION                         5       5        5           0
# AL-HARAMAIN ISLAMIC FOUNDATION                 5       5        4           0
# AQSSA SOCIETY                                  9       9        9           0
# AQSSA SOCIETY YEMEN                            9       9        9           0
# Bell Medical Billing                           6       6        0           0
# CHARITABLE AL-AQSA ESTABLISHMENT               9       9        9           0
# CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA   9       9        9           0
# CHERAN C. SANDERS                              5       5        5           0
# DUNN MEDICAL, INC                              8       8        1           0
# FORENINGEN AL-AQSA                             9       9        9           0
# ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA         9       9        9           0
# Kohll's Pharmacy and Homecare                  7       7        0           0
# LPN                                            8       8        0           0
# MICHAEL DAVIS                                  5       5        2           1
# MU' ASA AL-AQSA AL-KHAYRIYYA                   9       9        9           0
# MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA          9       9        9           0
# NUSRAT AL-AQSA AL-SHARIF                       8       8        8           0
# New England Brace Company, Inc.                5       5        0           0
# ROBERTO RODRIGUEZ                              5       5        0           3
# Raad Kouza                                     5       5        5           0
# SANABIL AL-AQSA CHARITABLE FOUNDATION          8       8        8           0
# SANDERS C. CHERAN                              5       5        5           0
# STICHTING AL-AQSA                              9       9        9           0
# SWEDISH CHARITABLE AQSA EST.                   9       9        9           0
# Shopko Pharmacy                                6       6        0           0
# Thomas J. Donahue                              5       5        1           0
# Thomas Prose                                   6       6        0           0
#
#                                               countries  addresses  \
# name
# AL-AQSA ASBL                                          0          0
# AL-AQSA CHARITABLE FOUNDATION                         0          0
# AL-AQSA CHARITABLE ORGANIZATION                       0          0
# AL-AQSA E.V.                                          1          1
# AL-AQSA FOUNDATION                                    3          3
# AL-AQSA INTERNATIONAL FOUNDATION                      0          0
# AL-AQSA ISLAMIC CHARITABLE SOCIETY                    0          0
# AL-AQSA SINABIL ESTABLISHMENT                         0          0
# AL-AQSA SPANM I STIFTELSE                             0          0
# AL-AQSA SPANMAL STIFTELSE                             0          0
# AL-HARAMAIN FOUNDATION                                0          0
# AL-HARAMAIN ISLAMIC FOUNDATION                        2          1
# AQSSA SOCIETY                                         0          0
# AQSSA SOCIETY YEMEN                                   1          1
# Bell Medical Billing                                  6          0
# CHARITABLE AL-AQSA ESTABLISHMENT                      0          0
# CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA          0          0
# CHERAN C. SANDERS                                     5          5
# DUNN MEDICAL, INC                                     8          8
# FORENINGEN AL-AQSA                                    1          1
# ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA                0          0
# Kohll's Pharmacy and Homecare                         7          0
# LPN                                                   8          8
# MICHAEL DAVIS                                         5          5
# MU' ASA AL-AQSA AL-KHAYRIYYA                          0          0
# MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA                 0          0
# NUSRAT AL-AQSA AL-SHARIF                              0          0
# New England Brace Company, Inc.                       5          0
# ROBERTO RODRIGUEZ                                     5          4
# Raad Kouza                                            5          5
# SANABIL AL-AQSA CHARITABLE FOUNDATION                 0          0
# SANDERS C. CHERAN                                     5          5
# STICHTING AL-AQSA                                     1          1
# SWEDISH CHARITABLE AQSA EST.                          0          0
# Shopko Pharmacy                                       6          0
# Thomas J. Donahue                                     5          2
# Thomas Prose                                          6          6
#
#                                               identifiers  sanctions  phones  \
# name
# AL-AQSA ASBL                                            8          8       0
# AL-AQSA CHARITABLE FOUNDATION                           9          9       0
# AL-AQSA CHARITABLE ORGANIZATION                         9          9       0
# AL-AQSA E.V.                                            9          9       0
# AL-AQSA FOUNDATION                                      9          9       0
# AL-AQSA INTERNATIONAL FOUNDATION                        9          9       0
# AL-AQSA ISLAMIC CHARITABLE SOCIETY                      9          9       0
# AL-AQSA SINABIL ESTABLISHMENT                           9          9       0
# AL-AQSA SPANM I STIFTELSE                               9          9       0
# AL-AQSA SPANMAL STIFTELSE                               9          9       0
# AL-HARAMAIN FOUNDATION                                  5          5       0
# AL-HARAMAIN ISLAMIC FOUNDATION                          5          5       0
# AQSSA SOCIETY                                           9          9       0
# AQSSA SOCIETY YEMEN                                     9          9       0
# Bell Medical Billing                                    6          6       0
# CHARITABLE AL-AQSA ESTABLISHMENT                        9          9       0
# CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA            9          9       0
# CHERAN C. SANDERS                                       0          5       0
# DUNN MEDICAL, INC                                       1          8       0
# FORENINGEN AL-AQSA                                      9          9       0
# ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA                  9          9       0
# Kohll's Pharmacy and Homecare                           7          7       0
# LPN                                                     0          8       0
# MICHAEL DAVIS                                           0          5       0
# MU' ASA AL-AQSA AL-KHAYRIYYA                            9          9       0
# MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA                   9          9       0
# NUSRAT AL-AQSA AL-SHARIF                                8          8       0
# New England Brace Company, Inc.                         5          5       0
# ROBERTO RODRIGUEZ                                       1          5       0
# Raad Kouza                                              5          5       0
# SANABIL AL-AQSA CHARITABLE FOUNDATION                   8          8       0
# SANDERS C. CHERAN                                       0          5       0
# STICHTING AL-AQSA                                       9          9       0
# SWEDISH CHARITABLE AQSA EST.                            9          9       0
# Shopko Pharmacy                                         6          6       0
# Thomas J. Donahue                                       5          5       0
# Thomas Prose                                            6          6       0
#
#                                               emails  dataset  first_seen  \
# name
# AL-AQSA ASBL                                       0        8           8
# AL-AQSA CHARITABLE FOUNDATION                      0        9           9
# AL-AQSA CHARITABLE ORGANIZATION                    0        9           9
# AL-AQSA E.V.                                       0        9           9
# AL-AQSA FOUNDATION                                 0        9           9
# AL-AQSA INTERNATIONAL FOUNDATION                   0        9           9
# AL-AQSA ISLAMIC CHARITABLE SOCIETY                 0        9           9
# AL-AQSA SINABIL ESTABLISHMENT                      0        9           9
# AL-AQSA SPANM I STIFTELSE                          0        9           9
# AL-AQSA SPANMAL STIFTELSE                          0        9           9
# AL-HARAMAIN FOUNDATION                             0        5           5
# AL-HARAMAIN ISLAMIC FOUNDATION                     0        5           5
# AQSSA SOCIETY                                      0        9           9
# AQSSA SOCIETY YEMEN                                0        9           9
# Bell Medical Billing                               0        6           6
# CHARITABLE AL-AQSA ESTABLISHMENT                   0        9           9
# CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA       0        9           9
# CHERAN C. SANDERS                                  0        5           5
# DUNN MEDICAL, INC                                  0        8           8
# FORENINGEN AL-AQSA                                 0        9           9
# ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA             0        9           9
# Kohll's Pharmacy and Homecare                      0        7           7
# LPN                                                0        8           8
# MICHAEL DAVIS                                      0        5           5
# MU' ASA AL-AQSA AL-KHAYRIYYA                       0        9           9
# MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA              0        9           9
# NUSRAT AL-AQSA AL-SHARIF                           0        8           8
# New England Brace Company, Inc.                    0        5           5
# ROBERTO RODRIGUEZ                                  0        5           5
# Raad Kouza                                         0        5           5
# SANABIL AL-AQSA CHARITABLE FOUNDATION              0        8           8
# SANDERS C. CHERAN                                  0        5           5
# STICHTING AL-AQSA                                  0        9           9
# SWEDISH CHARITABLE AQSA EST.                       0        9           9
# Shopko Pharmacy                                    0        6           6
# Thomas J. Donahue                                  0        5           5
# Thomas Prose                                       0        6           6
#
#                                               last_seen  last_change
# name
# AL-AQSA ASBL                                          8            8
# AL-AQSA CHARITABLE FOUNDATION                         9            9
# AL-AQSA CHARITABLE ORGANIZATION                       9            9
# AL-AQSA E.V.                                          9            9
# AL-AQSA FOUNDATION                                    9            9
# AL-AQSA INTERNATIONAL FOUNDATION                      9            9
# AL-AQSA ISLAMIC CHARITABLE SOCIETY                    9            9
# AL-AQSA SINABIL ESTABLISHMENT                         9            9
# AL-AQSA SPANM I STIFTELSE                             9            9
# AL-AQSA SPANMAL STIFTELSE                             9            9
# AL-HARAMAIN FOUNDATION                                5            5
# AL-HARAMAIN ISLAMIC FOUNDATION                        5            5
# AQSSA SOCIETY                                         9            9
# AQSSA SOCIETY YEMEN                                   9            9
# Bell Medical Billing                                  6            6
# CHARITABLE AL-AQSA ESTABLISHMENT                      9            9
# CHARITABLE SOCIETY TO HELP THE NOBLE AL-AQSA          9            9
# CHERAN C. SANDERS                                     5            5
# DUNN MEDICAL, INC                                     8            8
# FORENINGEN AL-AQSA                                    9            9
# ISLAMIC CHARITABLE SOCIETY FOR AL-AQSA                9            9
# Kohll's Pharmacy and Homecare                         7            7
# LPN                                                   8            8
# MICHAEL DAVIS                                         5            5
# MU' ASA AL-AQSA AL-KHAYRIYYA                          9            9
# MU' ASSA SANABIL AL-AQSA AL-KHAYRIYYA                 9            9
# NUSRAT AL-AQSA AL-SHARIF                              8            8
# New England Brace Company, Inc.                       5            5
# ROBERTO RODRIGUEZ                                     5            5
# Raad Kouza                                            5            5
# SANABIL AL-AQSA CHARITABLE FOUNDATION                 8            8
# SANDERS C. CHERAN                                     5            5
# STICHTING AL-AQSA                                     9            9
# SWEDISH CHARITABLE AQSA EST.                          9            9
# Shopko Pharmacy                                       6            6
# Thomas J. Donahue                                     5            5
# Thomas Prose                                          6            6

# %%
ted = pd.read_csv("/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/export_CAN_2019.csv")
# Out:
# /var/folders/r2/9vnxdxyd26380tms_8k538b40000gn/T/ipykernel_1517/3393530238.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ted = pd.read_csv("/Users/wiktorrajca/Desktop/Research/URAP_Fedyk/export_CAN_2019.csv")

# %%
ted["WIN_NATIONALID"].isna().sum()
# Out:
# np.int64(713147)

# %%
ted["WIN_NATIONALID"].isna().sum()/ted.shape[0]
# Out:
# np.float64(0.7197608827516045)

# %%
ted["WIN_COUNTRY_CODE"].isna().sum()/ted.shape[0]
# Out:
# np.float64(0.31477345326202477)

# %%
sanctions_merged = pd.read_csv("/Users/wiktorrajca/Documents/GitHub/Data-Science-Honors-Thesis/code/output_test/Sanctions/merged_result_3.csv")

# %%
sanctions_merged[sanctions_merged['name'] == 'ANTARES LLC']
# Out:
#                             id       schema         name  \
# 73   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 74   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 75   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 76   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 77   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 78   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 79   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 80   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 81   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 82   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 83   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 84   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 85   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 86   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 87   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 88   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 89   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 90   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 91   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 92   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 93   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 94   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 95   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 96   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 97   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 98   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 99   NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 100  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 101  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 102  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 103  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 104  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 105  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 106  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 107  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 108  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 109  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 110  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 111  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 112  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 113  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 114  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 115  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 116  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 117  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 118  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 119  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 120  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
# 121  NK-Gbik6Hp3G8o9nPkMzyq68M  LegalEntity  ANTARES LLC
#
#                                            aliases birth_date countries  \
# 73   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 74   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 75   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 76   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 77   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 78   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 79   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 80   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 81   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 82   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 83   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 84   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 85   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 86   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 87   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 88   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 89   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 90   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 91   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 92   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 93   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 94   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 95   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 96   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 97   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 98   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 99   ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 100  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 101  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 102  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 103  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 104  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 105  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 106  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 107  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 108  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 109  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 110  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 111  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 112  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 113  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 114  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 115  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 116  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 117  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 118  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 119  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 120  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
# 121  ANTARES OOO;LIMITED LIABILITY COMPANY ANTARES        NaN        ru
#
#                                              addresses  \
# 73   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 74   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 75   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 76   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 77   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 78   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 79   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 80   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 81   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 82   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 83   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 84   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 85   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 86   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 87   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 88   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 89   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 90   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 91   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 92   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 93   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 94   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 95   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 96   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 97   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 98   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 99   UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 100  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 101  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 102  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 103  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 104  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 105  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 106  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 107  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 108  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 109  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 110  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 111  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 112  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 113  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 114  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 115  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 116  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 117  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 118  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 119  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 120  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
# 121  UL. SMIRNOVSKAYA D. 10, STR. 8. KABINET 10, MO...
#
#                                 identifiers                sanctions  phones  \
# 73   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 74   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 75   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 76   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 77   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 78   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 79   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 80   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 81   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 82   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 83   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 84   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 85   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 86   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 87   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 88   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 89   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 90   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 91   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 92   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 93   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 94   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 95   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 96   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 97   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 98   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 99   C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 100  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 101  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 102  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 103  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 104  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 105  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 106  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 107  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 108  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 109  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 110  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 111  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 112  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 113  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 114  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 115  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 116  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 117  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 118  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 119  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 120  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
# 121  C1UFLB6D9TE5;N744BK9A7714;NAPRCFCSM743  Reciprocal - 2022-02-22     NaN
#
#      emails                        dataset           first_seen  \
# 73      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 74      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 75      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 76      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 77      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 78      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 79      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 80      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 81      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 82      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 83      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 84      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 85      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 86      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 87      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 88      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 89      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 90      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 91      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 92      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 93      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 94      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 95      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 96      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 97      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 98      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 99      NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 100     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 101     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 102     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 103     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 104     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 105     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 106     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 107     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 108     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 109     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 110     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 111     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 112     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 113     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 114     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 115     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 116     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 117     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 118     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 119     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 120     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
# 121     NaN  US SAM Procurement Exclusions  2024-06-14T06:55:20
#
#                last_seen          last_change       name.1     bvdidnumber
# 73   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA23792943
# 74   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA32033608
# 75   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25107408
# 76   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30145152
# 77   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC     UA258063607
# 78   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25342109
# 79   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25342010
# 80   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25418166
# 81   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25421107
# 82   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA22454210
# 83   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA26067220
# 84   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24273197
# 85   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24271353
# 86   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24275463
# 87   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24284870
# 88   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24142207
# 89   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24456928
# 90   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24472643
# 91   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24126875
# 92   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24027469
# 93   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC     UA509766097
# 94   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC     UA203795672
# 95   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC     UA203798752
# 96   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30393702
# 97   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA13718615
# 98   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA13609866
# 99   2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30058772
# 100  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30073099
# 101  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30253956
# 102  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30222184
# 103  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30237080
# 104  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA30315053
# 105  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25176289
# 106  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA25188526
# 107  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24672879
# 108  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA24662527
# 109  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA19044081
# 110  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA38684879
# 111  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC   UA*F000047990
# 112  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC   UA*G000749811
# 113  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC   UA*G000053446
# 114  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA23325259
# 115  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA23285778
# 116  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC   UA*G000946349
# 117  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC   UA*G001158888
# 118  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA36308324
# 119  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA32994976
# 120  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC      UA44053465
# 121  2025-01-07T07:55:02  2024-12-03T11:56:57  ANTARES LLC  UA*G0006728978

# %%
ted["WIN_NAME"].str.lower.str.contains('antares')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ted["WIN_NAME"].str.lower.str.contains('antares')
#
# AttributeError: 'function' object has no attribute 'str'

# %%
ted[ted["WIN_NAME"].str.lower().str.contains('antares', na=False)][['WIN_NAME', 'WIN_COUNTRY_CODE', 'WIN_TOWN']]
# Out:
#                                                  WIN_NAME  \
# 32829                                          Antares IT
# 34087                                          Antares TP
# 381102  Antares România S.R.L.---Ovo Design Furniture ...
# 410681   Antares Consulting — Consultoria de Gestão, Lda.
# 488364                                         Antares IT
# 488367                                         Antares IT
# 575617                                         Antares IT
# 730768                                         Antares IT
# 831237  Axis Specialty Ltd---Central Reinsurance Corpo...
#
#                                        WIN_COUNTRY_CODE  \
# 32829                                                FR
# 34087                                                FR
# 381102                                     RO---RO---RO
# 410681                                               PT
# 488364                                               FR
# 488367                                               FR
# 575617                                               FR
# 730768                                               FR
# 831237  BM---TW---CH---UK---UK---UK---DE---SE---JP---SI
#
#                                                  WIN_TOWN
# 32829                                    Levallois-Perret
# 34087                                        Baie-Mahault
# 381102                Cluj-Napoca---București---București
# 410681                                             Lisboa
# 488364                                   Levallois Perret
# 488367                                   Levallois Perret
# 575617                                   Levallois-Perret
# 730768                                   Levallois-Perret
# 831237  92 Pitts Bay Road, Pembroke, HM 08 Bermuda---1...

# %%
sanctions_merged
# Out:
#                              id       schema             name  \
# 0     NK-2CdXhyCy9XzyZgcFcHXrTZ  LegalEntity      LLC HAVERIM
# 1     NK-2DoNAuynq6QjpaKV4CqXX9  LegalEntity  LLC INTERRESURS
# 2     NK-2DoNAuynq6QjpaKV4CqXX9  LegalEntity  LLC INTERRESURS
# 3     NK-2DoNAuynq6QjpaKV4CqXX9  LegalEntity  LLC INTERRESURS
# 4     NK-2DoNAuynq6QjpaKV4CqXX9  LegalEntity  LLC INTERRESURS
# ...                         ...          ...              ...
# 2365            usgsa-s4mrtyf18  LegalEntity         ANDA CO.
# 2366            usgsa-s4mrtyf18  LegalEntity         ANDA CO.
# 2367            usgsa-s4mrtyf19  LegalEntity        ANDA LTD.
# 2368            usgsa-s4mrtyf19  LegalEntity        ANDA LTD.
# 2369               wbdeb-112929  LegalEntity    INFOTEK & CO.
#
#                                                 aliases birth_date countries  \
# 0     CHAVERIM;CHAVERIM LLC HAVERIM;LIMITED LIABILIT...        NaN        ru
# 1                                                   NaN        NaN        ru
# 2                                                   NaN        NaN        ru
# 3                                                   NaN        NaN        ru
# 4                                                   NaN        NaN        ru
# ...                                                 ...        ...       ...
# 2365                                       ANDA COMPANY        NaN        sa
# 2366                                       ANDA COMPANY        NaN        sa
# 2367                                       ANDA COMPANY        NaN        sa
# 2368                                       ANDA COMPANY        NaN        sa
# 2369                                                NaN        NaN        gb
#
#                                               addresses  \
# 0     NAB. OKTYABRSKAYA D. 104, K. 1 LIT. P, OFFICE ...
# 1     UL. MARSHALA GOVOROVA D. 35, KORPUS 4 LIT. I, ...
# 2     UL. MARSHALA GOVOROVA D. 35, KORPUS 4 LIT. I, ...
# 3     UL. MARSHALA GOVOROVA D. 35, KORPUS 4 LIT. I, ...
# 4     UL. MARSHALA GOVOROVA D. 35, KORPUS 4 LIT. I, ...
# ...                                                 ...
# 2365                                                NaN
# 2366                                                NaN
# 2367                                                NaN
# 2368                                                NaN
# 2369                             LONDON, United Kingdom
#
#                                  identifiers  \
# 0     EVFWEDMZY2C5;EVG4X9K8WUF4;LEY4MWR5LB45
# 1                               XZ52FKLQAEL9
# 2                               XZ52FKLQAEL9
# 3                               XZ52FKLQAEL9
# 4                               XZ52FKLQAEL9
# ...                                      ...
# 2365                            QQW2UKR4MVY5
# 2366                            QQW2UKR4MVY5
# 2367                            QQZ4GBGJE7N4
# 2368                            QQZ4GBGJE7N4
# 2369                                     NaN
#
#                                               sanctions  phones  emails  \
# 0                               Reciprocal - 2024-08-23     NaN     NaN
# 1                               Reciprocal - 2024-10-30     NaN     NaN
# 2                               Reciprocal - 2024-10-30     NaN     NaN
# 3                               Reciprocal - 2024-10-30     NaN     NaN
# 4                               Reciprocal - 2024-10-30     NaN     NaN
# ...                                                 ...     ...     ...
# 2365                            Reciprocal - 2022-05-24     NaN     NaN
# 2366                            Reciprocal - 2022-05-24     NaN     NaN
# 2367                            Reciprocal - 2022-05-24     NaN     NaN
# 2368                            Reciprocal - 2022-05-24     NaN     NaN
# 2369  Procurement Guidelines 1.15(a)(i) & (ii) - 200...     NaN     NaN
#
#                             dataset           first_seen            last_seen  \
# 0     US SAM Procurement Exclusions  2024-09-20T07:55:13  2025-01-07T07:55:02
# 1     US SAM Procurement Exclusions  2024-11-01T07:55:06  2025-01-07T07:55:02
# 2     US SAM Procurement Exclusions  2024-11-01T07:55:06  2025-01-07T07:55:02
# 3     US SAM Procurement Exclusions  2024-11-01T07:55:06  2025-01-07T07:55:02
# 4     US SAM Procurement Exclusions  2024-11-01T07:55:06  2025-01-07T07:55:02
# ...                             ...                  ...                  ...
# 2365  US SAM Procurement Exclusions  2024-11-02T07:55:02  2025-01-07T07:55:02
# 2366  US SAM Procurement Exclusions  2024-11-02T07:55:02  2025-01-07T07:55:02
# 2367  US SAM Procurement Exclusions  2024-11-02T07:55:02  2025-01-07T07:55:02
# 2368  US SAM Procurement Exclusions  2024-11-02T07:55:02  2025-01-07T07:55:02
# 2369   WorldBank Debarred Providers  2023-04-20T12:18:15  2025-01-07T15:03:01
#
#               last_change           name.1    bvdidnumber
# 0     2024-12-03T11:56:57      LLC HAVERIM     UA23839739
# 1     2024-12-03T11:56:57  LLC INTERRESURS     UA25865927
# 2     2024-12-03T11:56:57  LLC INTERRESURS     UA25760887
# 3     2024-12-03T11:56:57  LLC INTERRESURS     UA25760858
# 4     2024-12-03T11:56:57  LLC INTERRESURS     UA25257852
# ...                   ...              ...            ...
# 2365  2024-12-03T11:56:57         ANDA CO.     UA24130977
# 2366  2024-12-03T11:56:57         ANDA CO.     UA30297422
# 2367  2024-12-03T11:56:57        ANDA LTD.     UA24130977
# 2368  2024-12-03T11:56:57        ANDA LTD.     UA30297422
# 2369  2024-11-28T15:03:03    INFOTEK & CO.  UA*G001399230
#
# [2370 rows x 17 columns]

# %% [markdown]
# #### REMOVING FLAGGED ENTITIES

# %%
import networkx as nx
import os

def remove_flagged_entities(G, output_path="cleaned_graph_without_flags.graphml"):
    """
    Removes all flagged entity markings from the graph:
    - Deletes 'Flagged' type nodes
    - Deletes edges of type 'FLAGGED_LINK'
    - Removes 'flagged' and 'flagged_reason' attributes from remaining nodes
    Saves the cleaned graph to a new GraphML file.

    Parameters:
        G (networkx.Graph): The input graph.
        output_path (str): Path to save the cleaned graph.

    Returns:
        networkx.Graph: The cleaned graph.
    """
    G_cleaned = G.copy()

    # 1. Remove edges labeled 'FLAGGED_LINK'
    flagged_edges = [(u, v) for u, v, d in G_cleaned.edges(data=True)
                     if d.get("relationship") == "FLAGGED_LINK"]
    G_cleaned.remove_edges_from(flagged_edges)

    # 2. Remove all nodes of type 'Flagged'
    flagged_nodes = [n for n, d in G_cleaned.nodes(data=True)
                     if d.get("type") == "Flagged"]
    G_cleaned.remove_nodes_from(flagged_nodes)

    # 3. Clean attributes from companies that were marked flagged
    for node, data in G_cleaned.nodes(data=True):
        if "flagged" in data:
            del data["flagged"]
        if "flagged_reason" in data:
            del data["flagged_reason"]

    # 4. Save graph
    nx.write_graphml(G_cleaned, output_path)
    print(f"✅ Cleaned graph saved to {output_path}")
    return G_cleaned

# %%
france = nx.read_graphml(f"procurement_graph_FR_clean.graphml")

# %%
france_no_flag = remove_flagged_entities(france)
# Out:
# ✅ Cleaned graph saved to cleaned_graph_without_flags.graphml

# %%
summarize_graph(france_no_flag)
# Out:
# ===== Graph Summary =====
# Total Nodes: 606726
# Total Edges: 431001
#
# Node Types:
#   - Procurement: 270132
#   - Company: 336594
#
# Edge Types:
#   - WON: 270132
#   - CONTROLS: 12973
#   - OWNS: 147819
#   - SUBSIDIARY_OF: 77
#
# Flagged Companies: 0
# =========================

# %% [markdown]
# #### WORK ON STATISTICS AND ROBOUSTNESS

# %%
import pandas as pd
import networkx as nx
from collections import defaultdict
from tqdm import tqdm

def compute_expected_flagged_matches(flagged_df):
    """
    Compute expected number of flagged entity matches per name.
    """
    expected_matches = (
        flagged_df[flagged_df['schema'] == 'LegalEntity']
        .groupby('name')['id']
        .nunique()
        .to_dict()
    )
    country_by_name = (
        flagged_df[flagged_df['schema'] == 'LegalEntity']
        .dropna(subset=['countries'])
        .groupby('name')['countries']
        .first()
        .to_dict()
    )
    return expected_matches, country_by_name

def determine_flagged_robustness_level(node, G, expected_matches, country_by_name):
    """
    Determines the robustness level (1 to 3) for a flagged node.
    """
    name = G.nodes[node].get("name")
    country = G.nodes[node].get("country", "").upper()
    match_count = sum(
        1 for n, d in G.nodes(data=True)
        if d.get("flagged") == "True" and d.get("name") == name
    )
    expected = expected_matches.get(name, 1)
    correct_country = country_by_name.get(name, "").upper()
    
    if match_count <= expected and country == correct_country:
        return 3
    elif match_count <= expected:
        return 2
    else:
        return 1

def filter_graph_by_match_confidence(G, min_confidence="Very High"):
    """
    Returns a subgraph of G with nodes that have at least the given match confidence.
    """
    confidence_levels = ["SuperLow", "Low", "Medium", "High", "Very High"]
    keep_levels = confidence_levels[confidence_levels.index(min_confidence):]
    
    keep_nodes = [
        n for n, d in G.nodes(data=True)
        if d.get("type") != "Company" or d.get("match_confidence") in keep_levels
    ]
    return G.subgraph(keep_nodes).copy()

def compute_flagged_statistics(G, flagged_df):
    """
    Computes flagged entity stats across 15 robustness combinations.
    """
    expected_matches, country_by_name = compute_expected_flagged_matches(flagged_df)

    # Match confidence tiers
    match_conf_tiers = ["All", "No Low", "No Low/Medium", "High+", "Very High"]
    # Sanction match levels
    sanction_robust_levels = [1, 2, 3]

    summary = []

    for conf in match_conf_tiers:
        if conf == "All":
            G_sub = G.copy()
        else:
            min_conf = {
                "No Low": "Medium",
                "No Low/Medium": "High",
                "High+": "High",
                "Very High": "Very High"
            }[conf]
            G_sub = filter_graph_by_match_confidence(G, min_conf)

        for level in sanction_robust_levels:
            flagged_nodes = [
                n for n, d in G_sub.nodes(data=True)
                if d.get("flagged") == "True"
            ]

            if level > 1:
                filtered_flagged = []
                for n in flagged_nodes:
                    lvl = determine_flagged_robustness_level(n, G_sub, expected_matches, country_by_name)
                    if lvl >= level:
                        filtered_flagged.append(n)
                flagged_nodes = filtered_flagged

            winners = {
                n for n, d in G_sub.nodes(data=True)
                if d.get("type") == "Company" and d.get("bid_winner") == "True"
            }

            # Count direct flagged winners
            direct_flagged_winners = len(set(flagged_nodes).intersection(winners))

            # Count shortest path links
            linked_to_winners = 0
            for flagged in flagged_nodes:
                for winner in winners:
                    if nx.has_path(G_sub, flagged, winner) or nx.has_path(G_sub, winner, flagged):
                        linked_to_winners += 1
                        break

            summary.append({
                "Match_Confidence": conf,
                "Sanction_Robustness": level,
                "Flagged_Entities": len(flagged_nodes),
                "Direct_Winners": direct_flagged_winners,
                "Linked_to_Winners": linked_to_winners
            })

    return pd.DataFrame(summary)

# %%
compute_flagged_statistics(france, sanc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 compute_flagged_statistics(france, sanc)
#
# Cell In[63], line 109, in compute_flagged_statistics(G, flagged_df)
#     107 for flagged in flagged_nodes:
#     108     for winner in winners:
# --> 109         if nx.has_path(G_sub, flagged, winner) or nx.has_path(G_sub, winner, flagged):
#     110             linked_to_winners += 1
#     111             break
#
# File ~/Library/Python/3.9/lib/python/site-packages/networkx/utils/backends.py:409, in _dispatch.__call__(self, backend, *args, **kwargs)
#     406         self._sig = sig
#     407     return self._sig
# --> 409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
#     412         return self.orig_func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import networkx as nx
from collections import defaultdict
from tqdm import tqdm

def compute_flagged_statistics_with_logging(G, sanctions_df):
    """
    Compute statistics of how flagged nodes (companies or individuals) connect to procurement winners
    across different robustness levels.

    Parameters:
        G (nx.DiGraph): Cleaned graph.
        sanctions_df (pd.DataFrame): Full sanctions dataset (pre-matching).

    Returns:
        pd.DataFrame: Summary statistics across 15 robustness combinations.
    """

    print("🔍 Computing expected matches for flagged names...")
    # 1. Estimate expected match counts and countries for each name from full sanctions dataset
    expected_match_counts = sanctions_df.groupby("name")["id"].nunique().to_dict()
    expected_country_codes = sanctions_df.groupby("name")["countries"].apply(
        lambda x: set([code for sublist in x.dropna().str.split(",") for code in sublist])
    ).to_dict()

    print("🔍 Extracting flagged and procurement nodes...")
    # 2. Extract flagged and procurement-winning nodes
    flagged_nodes = {
        node: data for node, data in G.nodes(data=True)
        if data.get("type") == "Flagged" or data.get("flagged") == "True"
    }
    winner_nodes = {
        node for node, data in G.nodes(data=True)
        if data.get("type") == "Company" and data.get("bid_winner") == "True"
    }

    print("🔁 Precomputing paths up to length 3 from flagged to winner nodes...")
    # 3. Precompute shortest paths up to length 3
    shortest_paths = {}
    for f in tqdm(flagged_nodes, desc="Shortest paths"):
        shortest_paths[f] = {}
        try:
            paths = nx.single_source_shortest_path_length(G, f, cutoff=3)
            for target, dist in paths.items():
                if target in winner_nodes:
                    shortest_paths[f][target] = dist
        except nx.NetworkXError:
            continue

    print("⚙️ Defining robustness levels...")
    # 4. Define robustness levels
    match_filters = {
        "All": lambda d: True,
        "No Low": lambda d: d.get("match_confidence") not in {"Low"},
        "No Medium": lambda d: d.get("match_confidence") not in {"Low", "Medium"},
        "High+": lambda d: d.get("match_confidence") in {"High", "Very High"},
        "Very High": lambda d: d.get("match_confidence") == "Very High",
    }

    sanction_filters = {
        "All": lambda name, node: True,
        "Respect Expected": lambda name, node: True,  # limited by expected counts
        "Respect Expected + Country": lambda name, node: (
            node.get("country") in expected_country_codes.get(name, set())
        )
    }

    print("📊 Computing statistics for 15 robustness combinations...")
    rows = []

    for m_label, m_filter in match_filters.items():
        for s_label, s_filter in sanction_filters.items():
            print(f"🔍 Running {m_label} | {s_label}")
            filtered_flagged = []
            grouped = defaultdict(list)

            for node, data in flagged_nodes.items():
                name = data.get("name", "Unknown")
                if not m_filter(data):
                    continue
                if not s_filter(name, data):
                    continue
                grouped[name].append((node, data))

            # Apply expected match limit
            if s_label in {"Respect Expected", "Respect Expected + Country"}:
                for name, entries in grouped.items():
                    limit = expected_match_counts.get(name, len(entries))
                    filtered_flagged.extend([x for x in entries[:limit]])
            else:
                filtered_flagged = [x for lst in grouped.values() for x in lst]

            winner_flagged = 0
            dist_1, dist_2, dist_3plus = 0, 0, 0

            for node, _ in filtered_flagged:
                if node in winner_nodes:
                    winner_flagged += 1
                elif node in shortest_paths:
                    min_dist = min(shortest_paths[node].values(), default=None)
                    if min_dist == 1:
                        dist_1 += 1
                    elif min_dist == 2:
                        dist_2 += 1
                    elif min_dist == 3:
                        dist_3plus += 1

            rows.append({
                "Match_Level": m_label,
                "Sanction_Level": s_label,
                "Total_Flagged_Considered": len(filtered_flagged),
                "Flagged_Winners": winner_flagged,
                "Distance_1": dist_1,
                "Distance_2": dist_2,
                "Distance_3+": dist_3plus
            })

    result_df = pd.DataFrame(rows)
    print("✅ Statistics computation complete.")
    return result_df

# %%
results_france = compute_flagged_statistics_with_logging(france, sanc)
# Out:
# 🔍 Computing expected matches for flagged names...
# 🔍 Extracting flagged and procurement nodes...
# 🔁 Precomputing paths up to length 3 from flagged to winner nodes...
# Shortest paths: 100%|██████████| 663/663 [00:00<00:00, 38481.45it/s]
# ⚙️ Defining robustness levels...
# 📊 Computing statistics for 15 robustness combinations...
# 🔍 Running All | All
# 🔍 Running All | Respect Expected
# 🔍 Running All | Respect Expected + Country
# 🔍 Running No Low | All
# 🔍 Running No Low | Respect Expected
# 🔍 Running No Low | Respect Expected + Country
# 🔍 Running No Medium | All
# 🔍 Running No Medium | Respect Expected
# 🔍 Running No Medium | Respect Expected + Country
# 🔍 Running High+ | All
# 🔍 Running High+ | Respect Expected
# 🔍 Running High+ | Respect Expected + Country
# 🔍 Running Very High | All
# 🔍 Running Very High | Respect Expected
# 🔍 Running Very High | Respect Expected + Country
# ✅ Statistics computation complete.

# %%
results_france
# Out:
#    Match_Level              Sanction_Level  Total_Flagged_Considered  \
# 0          All                         All                       663
# 1          All            Respect Expected                       591
# 2          All  Respect Expected + Country                         0
# 3       No Low                         All                       376
# 4       No Low            Respect Expected                       376
# 5       No Low  Respect Expected + Country                         0
# 6    No Medium                         All                        26
# 7    No Medium            Respect Expected                        26
# 8    No Medium  Respect Expected + Country                         0
# 9        High+                         All                        17
# 10       High+            Respect Expected                        17
# 11       High+  Respect Expected + Country                         0
# 12   Very High                         All                        17
# 13   Very High            Respect Expected                        17
# 14   Very High  Respect Expected + Country                         0
#
#     Flagged_Winners  Distance_1  Distance_2  Distance_3+
# 0               654           4           0            0
# 1               582           4           0            0
# 2                 0           0           0            0
# 3               367           4           0            0
# 4               367           4           0            0
# 5                 0           0           0            0
# 6                17           4           0            0
# 7                17           4           0            0
# 8                 0           0           0            0
# 9                17           0           0            0
# 10               17           0           0            0
# 11                0           0           0            0
# 12               17           0           0            0
# 13               17           0           0            0
# 14                0           0           0            0

# %%
summarize_graph(france)
# Out:
# ===== Graph Summary =====
# Total Nodes: 606730
# Total Edges: 431038
#
# Node Types:
#   - Procurement: 270132
#   - Company: 336594
#   - Flagged: 4
#
# Edge Types:
#   - WON: 270132
#   - CONTROLS: 12973
#   - OWNS: 147819
#   - FLAGGED_LINK: 37
#   - SUBSIDIARY_OF: 77
#
# Flagged Companies: 659
# =========================
