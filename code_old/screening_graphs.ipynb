# %%
import networkx as nx
import requests, math, logging
from concurrent.futures import ThreadPoolExecutor, as_completed

# show only warnings+ by default
logging.basicConfig(level=logging.WARNING, format='%(asctime)s %(levelname)s: %(message)s')

DATASET_SCOPES = ["sanctions","peps","regulatory","crime"]

def is_valid(v):
    if v is None: 
        return False
    if isinstance(v, str):
        vv = v.strip().lower()
        if vv in ("", "nan", "unknown", "-"):
            return False
    if isinstance(v, float) and math.isnan(v):
        return False
    return True

def build_entity_payload(nid, data):
    name = data.get("the_name")
    if not is_valid(name):
        return None

    t = data.get("type","").strip().lower()
    if t=="company":
        schema="Company"
    elif t=="person":
        schema="Person"
    else:
        return None

    props = {"name":[name.strip()]}
    if schema=="Company" and is_valid(data.get("the_identifier")):
        props["registrationNumber"] = [data["the_identifier"].strip()]
    if is_valid(data.get("the_country")):
        c = data["the_country"].strip()
        props["jurisdiction" if schema=="Company" else "nationality"] = [c]
    if is_valid(data.get("the_postal_code")):
        props["postalCode"] = [data["the_postal_code"].strip()]
    if is_valid(data.get("the_town")):
        props["town"] = [data["the_town"].strip()]

    props.setdefault("identifiers", []).append({"source":"GraphID","value":str(nid)})
    return {"schema":schema,"properties":props}

def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

def _match_batch(scope, batch, all_queries, yente_base):
    """
    Thread‐friendly batch matcher.
    Returns list of (nid, record_dict).
    """
    url = f"{yente_base}/match/{scope}"
    payload = {"queries": {nid: all_queries[nid] for nid in batch}}
    try:
        r = requests.post(url, json=payload, timeout=30)
        r.raise_for_status()
    except Exception as e:
        logging.error("Scope %s batch failed: %s", scope, e)
        return [
            (nid, {
                "match_found": False,
                "dataset": scope
            }) 
            for nid in batch
        ]

    out = []
    reps = r.json().get("responses", {})
    for nid, res in reps.items():
        hits = res.get("results", [])
        if hits:
            top = hits[0]
            entity = top.get("entity", {})

            # 1) top‐level name property
            matched_name = entity.get("name")
            # 2) fallback to properties.name[0]
            if not matched_name:
                matched_name = entity.get("properties", {})\
                                     .get("name", [None])[0]
            # 3) fallback to ID
            if not matched_name:
                matched_name = entity.get("id")

            rec = {
                "match_found":   True,
                "matched_name":  matched_name,
                "matched_entity": entity,       # <-- full dict for debugging
                "dataset":       scope,
                "score":         top.get("score")
            }
        else:
            rec = {
                "match_found": False,
                "dataset":     scope
            }
        out.append((nid, rec))
    return out

def screen_graph_multi_threads(
    graph: nx.DiGraph,
    yente_base: str="http://localhost:8000",
    batch_size: int=50,
    max_workers: int=None
) -> nx.DiGraph:
    # build all queries
    all_q = {}
    for nid, data in graph.nodes(data=True):
        p = build_entity_payload(nid, data)
        if p:
            all_q[nid] = p
    if not all_q:
        logging.error("No valid nodes to screen.")
        return graph

    nodes = list(all_q.keys())
    total_batches = sum(math.ceil(len(nodes)/batch_size) for _ in DATASET_SCOPES)
    print(f"{len(nodes)} nodes → {total_batches} batches across {len(DATASET_SCOPES)} scopes.")

    if max_workers is None:
        import os
        max_workers = os.cpu_count() or 4

    with ThreadPoolExecutor(max_workers=max_workers) as exe:
        futures = []
        for scope in DATASET_SCOPES:
            for batch in chunks(nodes, batch_size):
                futures.append(
                    exe.submit(_match_batch, scope, batch, all_q, yente_base)
                )

        completed = 0
        for fut in as_completed(futures):
            completed += 1
            for nid, record in fut.result():
                graph.nodes[nid].setdefault("screening", {})[record["dataset"]] = record

            # progress every 100 batches
            if completed == 1 or completed % 100 == 0 or completed == len(futures):
                print(f"  completed {completed}/{len(futures)} batches")

    return graph

# Example (in Jupyter):
G = nx.DiGraph()
G.add_node("C1", type="Company", the_name="BlackRock, Inc.", the_identifier="US012345", the_postal_code="10022", the_town="New York", the_country="US")
G.add_node("P1", type="Person", the_name="Jane Doe", the_country="US")

# Run with 10 threads:
screened = screen_graph_multi_threads(G, batch_size=20, max_workers=10)

import json
for nid, data in screened.nodes(data=True):
    print(nid, json.dumps(data["screening"], indent=2))
# Out:
# /Users/wiktorrajca/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2 nodes → 4 batches across 4 scopes.
#   completed 1/4 batches
#   completed 4/4 batches
# C1 {
#   "regulatory": {
#     "match_found": true,
#     "matched_name": null,
#     "matched_entity": {},
#     "dataset": "regulatory",
#     "score": 0.75
#   },
#   "crime": {
#     "match_found": true,
#     "matched_name": null,
#     "matched_entity": {},
#     "dataset": "crime",
#     "score": 0.75
#   },
#   "peps": {
#     "match_found": false,
#     "dataset": "peps"
#   },
#   "sanctions": {
#     "match_found": false,
#     "dataset": "sanctions"
#   }
# }
# P1 {
#   "regulatory": {
#     "match_found": false,
#     "dataset": "regulatory"
#   },
#   "crime": {
#     "match_found": false,
#     "dataset": "crime"
#   },
#   "peps": {
#     "match_found": true,
#     "matched_name": null,
#     "matched_entity": {},
#     "dataset": "peps",
#     "score": 0.9
#   },
#   "sanctions": {
#     "match_found": false,
#     "dataset": "sanctions"
#   }
# }

# %%
graph = nx.read_graphml(f"/Users/wiktorrajca/Documents/GitHub/Data-Science-Honors-Thesis/code/procurement_graph_france_build_full_clean.graphml")

# %%
screened_graph = screen_graph_multi_threads(graph, batch_size=50, max_workers=10)
# Out:
# 408728 nodes → 32700 batches across 4 scopes.
#   completed 1/32700 batches

# %%
import os
import json
import math
import logging
import pandas as pd
import networkx as nx
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed

# show only warnings+ by default
logging.basicConfig(level=logging.WARNING, format='%(asctime)s %(levelname)s: %(message)s')

DATASET_SCOPES = ["sanctions", "peps", "regulatory", "crime"]

def is_valid(v):
    if v is None:
        return False
    if isinstance(v, str):
        vv = v.strip().lower()
        if vv in ("", "nan", "unknown", "-"):
            return False
    if isinstance(v, float) and math.isnan(v):
        return False
    return True

def build_entity_payload(nid, data):
    name = data.get("the_name")
    if not is_valid(name):
        return None

    t = data.get("type", "").strip().lower()
    if t == "company":
        schema = "Company"
    elif t == "person":
        schema = "Person"
    else:
        return None

    props = {"name": [name.strip()]}
    if schema == "Company" and is_valid(data.get("the_identifier")):
        props["registrationNumber"] = [data["the_identifier"].strip()]
    if is_valid(data.get("the_country")):
        c = data["the_country"].strip()
        props["jurisdiction" if schema == "Company" else "nationality"] = [c]
    if is_valid(data.get("the_postal_code")):
        props["postalCode"] = [data["the_postal_code"].strip()]
    if is_valid(data.get("the_town")):
        props["town"] = [data["the_town"].strip()]

    props.setdefault("identifiers", []).append({"source": "GraphID", "value": str(nid)})
    return {"schema": schema, "properties": props}

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

def _match_batch(scope, batch, all_queries, yente_base):
    """
    Thread-friendly batch matcher.
    Returns list of (nid, record_dict).
    """
    url = f"{yente_base}/match/{scope}"
    payload = {"queries": {nid: all_queries[nid] for nid in batch}}
    try:
        r = requests.post(url, json=payload, timeout=60)
        r.raise_for_status()
    except Exception as e:
        logging.error("Scope %s batch failed: %s", scope, e)
        return [
            (nid, {
                "match_found": False,
                "dataset": scope
            })
            for nid in batch
        ]

    out = []
    reps = r.json().get("responses", {})
    for nid, res in reps.items():
        hits = res.get("results", [])
        if hits:
            top = hits[0]
            entity = top.get("entity", {})

            # 1) top-level name property
            matched_name = entity.get("name")
            # 2) fallback to properties.name[0]
            if not matched_name:
                matched_name = entity.get("properties", {})\
                                     .get("name", [None])[0]
            # 3) fallback to ID
            if not matched_name:
                matched_name = entity.get("id")

            rec = {
                "match_found":   True,
                "matched_name":  matched_name,
                "matched_entity": entity,       # full dict for debugging
                "dataset":       scope,
                "score":         top.get("score")
            }
        else:
            rec = {
                "match_found": False,
                "dataset":     scope
            }
        out.append((nid, rec))
    return out

def screen_graph_multi_threads(
    graph: nx.DiGraph,
    yente_base: str = "http://localhost:8000",
    batch_size: int = 50,
    max_workers: int = None,
    checkpoint_file: str = "screening_checkpoint.csv",
    checkpoint_frequency: int = 100
) -> nx.DiGraph:
    """
    Multi-threaded screening with CSV checkpointing & resume support.
    - checkpoint_file: path to the CSV (overwritten at start, appended thereafter)
    - checkpoint_frequency: how many batches between writes
    """
    # 1) Load or initialize checkpoint
    if os.path.exists(checkpoint_file):
        df_exist = pd.read_csv(checkpoint_file, dtype=str)
        skip_pairs = set(zip(df_exist['node_id'], df_exist['dataset']))
    else:
        pd.DataFrame(
            columns=['node_id','dataset','match_found','matched_name','score','record_json']
        ).to_csv(checkpoint_file, index=False)
        skip_pairs = set()

    # 2) Build all queries
    all_q = {}
    for nid, data in graph.nodes(data=True):
        p = build_entity_payload(nid, data)
        if p:
            all_q[nid] = p
    if not all_q:
        logging.error("No valid nodes to screen.")
        return graph

    nodes = list(all_q.keys())

    # 3) Prepare pending batches
    batches = []
    for scope in DATASET_SCOPES:
        pending = [nid for nid in nodes if (nid, scope) not in skip_pairs]
        for b in chunks(pending, batch_size):
            batches.append((scope, b))

    total_batches = len(batches)
    print(f"{len(nodes)} nodes → {total_batches} pending batches across {len(DATASET_SCOPES)} scopes.")

    if max_workers is None:
        max_workers = os.cpu_count() or 4

    # 4) Execute & checkpoint
    with ThreadPoolExecutor(max_workers=max_workers) as exe:
        future_map = {
            exe.submit(_match_batch, scope, batch, all_q, yente_base): (scope, batch)
            for scope, batch in batches
        }

        completed = 0
        buffer = []

        for fut in as_completed(future_map):
            completed += 1
            scope, batch = future_map[fut]
            try:
                results = fut.result()
            except Exception as e:
                logging.error("Batch %s/%s failed: %s", scope, batch, e)
                results = [(nid, {"match_found": False, "dataset": scope}) for nid in batch]

            for nid, rec in results:
                buffer.append({
                    'node_id':      nid,
                    'dataset':      rec.get('dataset', scope),
                    'match_found':  rec.get('match_found', False),
                    'matched_name': rec.get('matched_name', ''),
                    'score':        rec.get('score', None),
                    'record_json':  json.dumps(rec)
                })

            # flush buffer to CSV periodically or at end
            if checkpoint_frequency > 0 and (completed % checkpoint_frequency == 0 or completed == total_batches):
                pd.DataFrame(buffer).to_csv(
                    checkpoint_file,
                    mode='a',
                    index=False,
                    header=False
                )
                buffer.clear()
                print(f"  → checkpointed after {completed} batches")

            # progress log
            if completed == 1 or completed % 100 == 0 or completed == total_batches:
                print(f"  completed {completed}/{total_batches} batches")

    return graph

if __name__ == "__main__":
    # Example usage in a standalone script
    G = nx.DiGraph()
    G.add_node("C1", type="Company", the_name="BlackRock, Inc.",
               the_identifier="US012345", the_postal_code="10022",
               the_town="New York", the_country="US")
    G.add_node("P1", type="Person", the_name="Jane Doe", the_country="US")

    screened = screen_graph_multi_threads(
        G,
        yente_base="http://localhost:8000",
        batch_size=20,
        max_workers=10,
        checkpoint_file="screening_checkpoint.csv",
        checkpoint_frequency=50
    )

    # Print out the raw screening CSV path for later ingestion
    print("Screening results checkpointed to:", os.path.abspath("screening_checkpoint.csv"))
# Out:
# 2 nodes → 4 pending batches across 4 scopes.
#   completed 1/4 batches
#   → checkpointed after 4 batches
#   completed 4/4 batches
# Screening results checkpointed to: /Users/wiktorrajca/Documents/GitHub/Data-Science-Honors-Thesis/code/screening_checkpoint.csv

# %%
screen_graph_multi_threads(graph)
# Out:
# 408728 nodes → 32700 pending batches across 4 scopes.
#   completed 1/32700 batches
#   → checkpointed after 100 batches
#   completed 100/32700 batches
#   → checkpointed after 200 batches
#   completed 200/32700 batches
#   → checkpointed after 300 batches
#   completed 300/32700 batches
#   → checkpointed after 400 batches
#   completed 400/32700 batches
#   → checkpointed after 500 batches
#   completed 500/32700 batches
#   → checkpointed after 600 batches
#   completed 600/32700 batches
#   → checkpointed after 700 batches
#   completed 700/32700 batches
#   → checkpointed after 800 batches
#   completed 800/32700 batches
#   → checkpointed after 900 batches
#   completed 900/32700 batches
#   → checkpointed after 1000 batches
#   completed 1000/32700 batches
#   → checkpointed after 1100 batches
#   completed 1100/32700 batches
#   → checkpointed after 1200 batches
#   completed 1200/32700 batches
#   → checkpointed after 1300 batches
#   completed 1300/32700 batches
#   → checkpointed after 1400 batches
#   completed 1400/32700 batches
#   → checkpointed after 1500 batches
#   completed 1500/32700 batches
#   → checkpointed after 1600 batches
#   completed 1600/32700 batches
#   → checkpointed after 1700 batches
#   completed 1700/32700 batches
#   → checkpointed after 1800 batches
#   completed 1800/32700 batches
#   → checkpointed after 1900 batches
#   completed 1900/32700 batches
#   → checkpointed after 2000 batches
#   completed 2000/32700 batches
#   → checkpointed after 2100 batches
#   completed 2100/32700 batches
#   → checkpointed after 2200 batches
#   completed 2200/32700 batches
#   → checkpointed after 2300 batches
#   completed 2300/32700 batches
#   → checkpointed after 2400 batches
#   completed 2400/32700 batches
#   → checkpointed after 2500 batches
#   completed 2500/32700 batches
#   → checkpointed after 2600 batches
#   completed 2600/32700 batches
#   → checkpointed after 2700 batches
#   completed 2700/32700 batches
#   → checkpointed after 2800 batches
#   completed 2800/32700 batches
#   → checkpointed after 2900 batches
#   completed 2900/32700 batches
#   → checkpointed after 3000 batches
#   completed 3000/32700 batches
#   → checkpointed after 3100 batches
#   completed 3100/32700 batches
#   → checkpointed after 3200 batches
#   completed 3200/32700 batches
#   → checkpointed after 3300 batches
#   completed 3300/32700 batches
#   → checkpointed after 3400 batches
#   completed 3400/32700 batches
#   → checkpointed after 3500 batches
#   completed 3500/32700 batches
#   → checkpointed after 3600 batches
#   completed 3600/32700 batches
#   → checkpointed after 3700 batches
#   completed 3700/32700 batches
#   → checkpointed after 3800 batches
#   completed 3800/32700 batches
#   → checkpointed after 3900 batches
#   completed 3900/32700 batches
#   → checkpointed after 4000 batches
#   completed 4000/32700 batches
#   → checkpointed after 4100 batches
#   completed 4100/32700 batches
#   → checkpointed after 4200 batches
#   completed 4200/32700 batches
#   → checkpointed after 4300 batches
#   completed 4300/32700 batches
#   → checkpointed after 4400 batches
#   completed 4400/32700 batches
#   → checkpointed after 4500 batches
#   completed 4500/32700 batches
#   → checkpointed after 4600 batches
#   completed 4600/32700 batches
#   → checkpointed after 4700 batches
#   completed 4700/32700 batches
#   → checkpointed after 4800 batches
#   completed 4800/32700 batches
#   → checkpointed after 4900 batches
#   completed 4900/32700 batches
#   → checkpointed after 5000 batches
#   completed 5000/32700 batches
#   → checkpointed after 5100 batches
#   completed 5100/32700 batches
#   → checkpointed after 5200 batches
#   completed 5200/32700 batches
#   → checkpointed after 5300 batches
#   completed 5300/32700 batches
#   → checkpointed after 5400 batches
#   completed 5400/32700 batches
#   → checkpointed after 5500 batches
#   completed 5500/32700 batches
#   → checkpointed after 5600 batches
#   completed 5600/32700 batches
#   → checkpointed after 5700 batches
#   completed 5700/32700 batches
#   → checkpointed after 5800 batches
#   completed 5800/32700 batches
#   → checkpointed after 5900 batches
#   completed 5900/32700 batches
#   → checkpointed after 6000 batches
#   completed 6000/32700 batches
#   → checkpointed after 6100 batches
#   completed 6100/32700 batches
#   → checkpointed after 6200 batches
#   completed 6200/32700 batches
#   → checkpointed after 6300 batches
#   completed 6300/32700 batches
#   → checkpointed after 6400 batches
#   completed 6400/32700 batches
#   → checkpointed after 6500 batches
#   completed 6500/32700 batches
#   → checkpointed after 6600 batches
#   completed 6600/32700 batches
#   → checkpointed after 6700 batches
#   completed 6700/32700 batches
#   → checkpointed after 6800 batches
#   completed 6800/32700 batches
#   → checkpointed after 6900 batches
#   completed 6900/32700 batches
#   → checkpointed after 7000 batches
#   completed 7000/32700 batches
#   → checkpointed after 7100 batches
#   completed 7100/32700 batches
#   → checkpointed after 7200 batches
#   completed 7200/32700 batches
#   → checkpointed after 7300 batches
#   completed 7300/32700 batches
#   → checkpointed after 7400 batches
#   completed 7400/32700 batches
#   → checkpointed after 7500 batches
#   completed 7500/32700 batches
#   → checkpointed after 7600 batches
#   completed 7600/32700 batches
#   → checkpointed after 7700 batches
#   completed 7700/32700 batches
#   → checkpointed after 7800 batches
#   completed 7800/32700 batches
#   → checkpointed after 7900 batches
#   completed 7900/32700 batches
#   → checkpointed after 8000 batches
#   completed 8000/32700 batches
#   → checkpointed after 8100 batches
#   completed 8100/32700 batches
#   → checkpointed after 8200 batches
#   completed 8200/32700 batches
#   → checkpointed after 8300 batches
#   completed 8300/32700 batches
#   → checkpointed after 8400 batches
#   completed 8400/32700 batches
#   → checkpointed after 8500 batches
#   completed 8500/32700 batches
#   → checkpointed after 8600 batches
#   completed 8600/32700 batches
#   → checkpointed after 8700 batches
#   completed 8700/32700 batches
#   → checkpointed after 8800 batches
#   completed 8800/32700 batches
#   → checkpointed after 8900 batches
#   completed 8900/32700 batches
#   → checkpointed after 9000 batches
#   completed 9000/32700 batches
#   → checkpointed after 9100 batches
#   completed 9100/32700 batches
#   → checkpointed after 9200 batches
#   completed 9200/32700 batches
#   → checkpointed after 9300 batches
#   completed 9300/32700 batches
#   → checkpointed after 9400 batches
#   completed 9400/32700 batches
#   → checkpointed after 9500 batches
#   completed 9500/32700 batches
#   → checkpointed after 9600 batches
#   completed 9600/32700 batches
#   → checkpointed after 9700 batches
#   completed 9700/32700 batches
#   → checkpointed after 9800 batches
#   completed 9800/32700 batches
#   → checkpointed after 9900 batches
#   completed 9900/32700 batches
#   → checkpointed after 10000 batches
#   completed 10000/32700 batches
#   → checkpointed after 10100 batches
#   completed 10100/32700 batches
#   → checkpointed after 10200 batches
#   completed 10200/32700 batches
#   → checkpointed after 10300 batches
#   completed 10300/32700 batches
#   → checkpointed after 10400 batches
#   completed 10400/32700 batches
#   → checkpointed after 10500 batches
#   completed 10500/32700 batches
#   → checkpointed after 10600 batches
#   completed 10600/32700 batches
#   → checkpointed after 10700 batches
#   completed 10700/32700 batches
#   → checkpointed after 10800 batches
#   completed 10800/32700 batches
#   → checkpointed after 10900 batches
#   completed 10900/32700 batches
#   → checkpointed after 11000 batches
#   completed 11000/32700 batches
#   → checkpointed after 11100 batches
#   completed 11100/32700 batches
#   → checkpointed after 11200 batches
#   completed 11200/32700 batches
#   → checkpointed after 11300 batches
#   completed 11300/32700 batches
#   → checkpointed after 11400 batches
#   completed 11400/32700 batches
#   → checkpointed after 11500 batches
#   completed 11500/32700 batches
#   → checkpointed after 11600 batches
#   completed 11600/32700 batches
#   → checkpointed after 11700 batches
#   completed 11700/32700 batches
#   → checkpointed after 11800 batches
#   completed 11800/32700 batches
#   → checkpointed after 11900 batches
#   completed 11900/32700 batches
#   → checkpointed after 12000 batches
#   completed 12000/32700 batches
#   → checkpointed after 12100 batches
#   completed 12100/32700 batches
#   → checkpointed after 12200 batches
#   completed 12200/32700 batches
#   → checkpointed after 12300 batches
#   completed 12300/32700 batches
#   → checkpointed after 12400 batches
#   completed 12400/32700 batches
#   → checkpointed after 12500 batches
#   completed 12500/32700 batches
#   → checkpointed after 12600 batches
#   completed 12600/32700 batches
#   → checkpointed after 12700 batches
#   completed 12700/32700 batches
#   → checkpointed after 12800 batches
#   completed 12800/32700 batches
#   → checkpointed after 12900 batches
#   completed 12900/32700 batches
#   → checkpointed after 13000 batches
#   completed 13000/32700 batches
#   → checkpointed after 13100 batches
#   completed 13100/32700 batches
#   → checkpointed after 13200 batches
#   completed 13200/32700 batches
#   → checkpointed after 13300 batches
#   completed 13300/32700 batches
#   → checkpointed after 13400 batches
#   completed 13400/32700 batches
#   → checkpointed after 13500 batches
#   completed 13500/32700 batches
#   → checkpointed after 13600 batches
#   completed 13600/32700 batches
#   → checkpointed after 13700 batches
#   completed 13700/32700 batches
#   → checkpointed after 13800 batches
#   completed 13800/32700 batches
#   → checkpointed after 13900 batches
#   completed 13900/32700 batches
#   → checkpointed after 14000 batches
#   completed 14000/32700 batches
#   → checkpointed after 14100 batches
#   completed 14100/32700 batches
#   → checkpointed after 14200 batches
#   completed 14200/32700 batches
#   → checkpointed after 14300 batches
#   completed 14300/32700 batches
#   → checkpointed after 14400 batches
#   completed 14400/32700 batches
#   → checkpointed after 14500 batches
#   completed 14500/32700 batches
#   → checkpointed after 14600 batches
#   completed 14600/32700 batches
#   → checkpointed after 14700 batches
#   completed 14700/32700 batches
#   → checkpointed after 14800 batches
#   completed 14800/32700 batches
#   → checkpointed after 14900 batches
#   completed 14900/32700 batches
#   → checkpointed after 15000 batches
#   completed 15000/32700 batches
#   → checkpointed after 15100 batches
#   completed 15100/32700 batches
#   → checkpointed after 15200 batches
#   completed 15200/32700 batches
#   → checkpointed after 15300 batches
#   completed 15300/32700 batches
#   → checkpointed after 15400 batches
#   completed 15400/32700 batches
#   → checkpointed after 15500 batches
#   completed 15500/32700 batches
#   → checkpointed after 15600 batches
#   completed 15600/32700 batches
#   → checkpointed after 15700 batches
#   completed 15700/32700 batches
#   → checkpointed after 15800 batches
#   completed 15800/32700 batches
#   → checkpointed after 15900 batches
#   completed 15900/32700 batches
#   → checkpointed after 16000 batches
#   completed 16000/32700 batches
#   → checkpointed after 16100 batches
#   completed 16100/32700 batches
#   → checkpointed after 16200 batches
#   completed 16200/32700 batches
#   → checkpointed after 16300 batches
#   completed 16300/32700 batches
#   → checkpointed after 16400 batches
#   completed 16400/32700 batches
#   → checkpointed after 16500 batches
#   completed 16500/32700 batches
#   → checkpointed after 16600 batches
#   completed 16600/32700 batches
#   → checkpointed after 16700 batches
#   completed 16700/32700 batches
#   → checkpointed after 16800 batches
#   completed 16800/32700 batches
#   → checkpointed after 16900 batches
#   completed 16900/32700 batches
#   → checkpointed after 17000 batches
#   completed 17000/32700 batches
#   → checkpointed after 17100 batches
#   completed 17100/32700 batches
#   → checkpointed after 17200 batches
#   completed 17200/32700 batches
#   → checkpointed after 17300 batches
#   completed 17300/32700 batches
#   → checkpointed after 17400 batches
#   completed 17400/32700 batches
#   → checkpointed after 17500 batches
#   completed 17500/32700 batches
#   → checkpointed after 17600 batches
#   completed 17600/32700 batches
#   → checkpointed after 17700 batches
#   completed 17700/32700 batches
#   → checkpointed after 17800 batches
#   completed 17800/32700 batches
#   → checkpointed after 17900 batches
#   completed 17900/32700 batches
#   → checkpointed after 18000 batches
#   completed 18000/32700 batches
#   → checkpointed after 18100 batches
#   completed 18100/32700 batches
#   → checkpointed after 18200 batches
#   completed 18200/32700 batches
#   → checkpointed after 18300 batches
#   completed 18300/32700 batches
#   → checkpointed after 18400 batches
#   completed 18400/32700 batches
#   → checkpointed after 18500 batches
#   completed 18500/32700 batches
#   → checkpointed after 18600 batches
#   completed 18600/32700 batches
#   → checkpointed after 18700 batches
#   completed 18700/32700 batches
#   → checkpointed after 18800 batches
#   completed 18800/32700 batches
#   → checkpointed after 18900 batches
#   completed 18900/32700 batches
#   → checkpointed after 19000 batches
#   completed 19000/32700 batches
#   → checkpointed after 19100 batches
#   completed 19100/32700 batches
#   → checkpointed after 19200 batches
#   completed 19200/32700 batches
#   → checkpointed after 19300 batches
#   completed 19300/32700 batches
#   → checkpointed after 19400 batches
#   completed 19400/32700 batches
#   → checkpointed after 19500 batches
#   completed 19500/32700 batches
#   → checkpointed after 19600 batches
#   completed 19600/32700 batches
#   → checkpointed after 19700 batches
#   completed 19700/32700 batches
#   → checkpointed after 19800 batches
#   completed 19800/32700 batches
#   → checkpointed after 19900 batches
#   completed 19900/32700 batches
#   → checkpointed after 20000 batches
#   completed 20000/32700 batches
#   → checkpointed after 20100 batches
#   completed 20100/32700 batches
#   → checkpointed after 20200 batches
#   completed 20200/32700 batches
#   → checkpointed after 20300 batches
#   completed 20300/32700 batches
#   → checkpointed after 20400 batches
#   completed 20400/32700 batches
#   → checkpointed after 20500 batches
#   completed 20500/32700 batches
#   → checkpointed after 20600 batches
#   completed 20600/32700 batches
#   → checkpointed after 20700 batches
#   completed 20700/32700 batches
#   → checkpointed after 20800 batches
#   completed 20800/32700 batches
#   → checkpointed after 20900 batches
#   completed 20900/32700 batches
#   → checkpointed after 21000 batches
#   completed 21000/32700 batches
#   → checkpointed after 21100 batches
#   completed 21100/32700 batches
#   → checkpointed after 21200 batches
#   completed 21200/32700 batches
#   → checkpointed after 21300 batches
#   completed 21300/32700 batches
#   → checkpointed after 21400 batches
#   completed 21400/32700 batches
#   → checkpointed after 21500 batches
#   completed 21500/32700 batches
#   → checkpointed after 21600 batches
#   completed 21600/32700 batches
#   → checkpointed after 21700 batches
#   completed 21700/32700 batches
#   → checkpointed after 21800 batches
#   completed 21800/32700 batches
#   → checkpointed after 21900 batches
#   completed 21900/32700 batches
#   → checkpointed after 22000 batches
#   completed 22000/32700 batches
#   → checkpointed after 22100 batches
#   completed 22100/32700 batches
#   → checkpointed after 22200 batches
#   completed 22200/32700 batches
#   → checkpointed after 22300 batches
#   completed 22300/32700 batches
#   → checkpointed after 22400 batches
#   completed 22400/32700 batches
#   → checkpointed after 22500 batches
#   completed 22500/32700 batches
#   → checkpointed after 22600 batches
#   completed 22600/32700 batches
#   → checkpointed after 22700 batches
#   completed 22700/32700 batches
#   → checkpointed after 22800 batches
#   completed 22800/32700 batches
#   → checkpointed after 22900 batches
#   completed 22900/32700 batches
#   → checkpointed after 23000 batches
#   completed 23000/32700 batches
#   → checkpointed after 23100 batches
#   completed 23100/32700 batches
#   → checkpointed after 23200 batches
#   completed 23200/32700 batches
#   → checkpointed after 23300 batches
#   completed 23300/32700 batches
#   → checkpointed after 23400 batches
#   completed 23400/32700 batches
#   → checkpointed after 23500 batches
#   completed 23500/32700 batches
#   → checkpointed after 23600 batches
#   completed 23600/32700 batches
#   → checkpointed after 23700 batches
#   completed 23700/32700 batches
#   → checkpointed after 23800 batches
#   completed 23800/32700 batches
#   → checkpointed after 23900 batches
#   completed 23900/32700 batches
#   → checkpointed after 24000 batches
#   completed 24000/32700 batches
#   → checkpointed after 24100 batches
#   completed 24100/32700 batches
#   → checkpointed after 24200 batches
#   completed 24200/32700 batches
#   → checkpointed after 24300 batches
#   completed 24300/32700 batches
#   → checkpointed after 24400 batches
#   completed 24400/32700 batches
#   → checkpointed after 24500 batches
#   completed 24500/32700 batches
#   → checkpointed after 24600 batches
#   completed 24600/32700 batches
#   → checkpointed after 24700 batches
#   completed 24700/32700 batches
#   → checkpointed after 24800 batches
#   completed 24800/32700 batches
#   → checkpointed after 24900 batches
#   completed 24900/32700 batches
#   → checkpointed after 25000 batches
#   completed 25000/32700 batches
#   → checkpointed after 25100 batches
#   completed 25100/32700 batches
#   → checkpointed after 25200 batches
#   completed 25200/32700 batches
#   → checkpointed after 25300 batches
#   completed 25300/32700 batches
#   → checkpointed after 25400 batches
#   completed 25400/32700 batches
#   → checkpointed after 25500 batches
#   completed 25500/32700 batches
#   → checkpointed after 25600 batches
#   completed 25600/32700 batches
#   → checkpointed after 25700 batches
#   completed 25700/32700 batches
#   → checkpointed after 25800 batches
#   completed 25800/32700 batches
#   → checkpointed after 25900 batches
#   completed 25900/32700 batches
#   → checkpointed after 26000 batches
#   completed 26000/32700 batches
#   → checkpointed after 26100 batches
#   completed 26100/32700 batches
#   → checkpointed after 26200 batches
#   completed 26200/32700 batches
#   → checkpointed after 26300 batches
#   completed 26300/32700 batches
#   → checkpointed after 26400 batches
#   completed 26400/32700 batches
#   → checkpointed after 26500 batches
#   completed 26500/32700 batches
#   → checkpointed after 26600 batches
#   completed 26600/32700 batches
#   → checkpointed after 26700 batches
#   completed 26700/32700 batches
#   → checkpointed after 26800 batches
#   completed 26800/32700 batches
#   → checkpointed after 26900 batches
#   completed 26900/32700 batches
#   → checkpointed after 27000 batches
#   completed 27000/32700 batches
#   → checkpointed after 27100 batches
#   completed 27100/32700 batches
#   → checkpointed after 27200 batches
#   completed 27200/32700 batches
#   → checkpointed after 27300 batches
#   completed 27300/32700 batches
#   → checkpointed after 27400 batches
#   completed 27400/32700 batches
#   → checkpointed after 27500 batches
#   completed 27500/32700 batches
#   → checkpointed after 27600 batches
#   completed 27600/32700 batches
#   → checkpointed after 27700 batches
#   completed 27700/32700 batches
#   → checkpointed after 27800 batches
#   completed 27800/32700 batches
#   → checkpointed after 27900 batches
#   completed 27900/32700 batches
#   → checkpointed after 28000 batches
#   completed 28000/32700 batches
#   → checkpointed after 28100 batches
#   completed 28100/32700 batches
#   → checkpointed after 28200 batches
#   completed 28200/32700 batches
#   → checkpointed after 28300 batches
#   completed 28300/32700 batches
#   → checkpointed after 28400 batches
#   completed 28400/32700 batches
#   → checkpointed after 28500 batches
#   completed 28500/32700 batches
#   → checkpointed after 28600 batches
#   completed 28600/32700 batches
#   → checkpointed after 28700 batches
#   completed 28700/32700 batches
#   → checkpointed after 28800 batches
#   completed 28800/32700 batches
#   → checkpointed after 28900 batches
#   completed 28900/32700 batches
#   → checkpointed after 29000 batches
#   completed 29000/32700 batches
#   → checkpointed after 29100 batches
#   completed 29100/32700 batches
#   → checkpointed after 29200 batches
#   completed 29200/32700 batches
#   → checkpointed after 29300 batches
#   completed 29300/32700 batches
#   → checkpointed after 29400 batches
#   completed 29400/32700 batches
#   → checkpointed after 29500 batches
#   completed 29500/32700 batches
#   → checkpointed after 29600 batches
#   completed 29600/32700 batches
#   → checkpointed after 29700 batches
#   completed 29700/32700 batches
#   → checkpointed after 29800 batches
#   completed 29800/32700 batches
#   → checkpointed after 29900 batches
#   completed 29900/32700 batches
#   → checkpointed after 30000 batches
#   completed 30000/32700 batches
#   → checkpointed after 30100 batches
#   completed 30100/32700 batches
#   → checkpointed after 30200 batches
#   completed 30200/32700 batches
#   → checkpointed after 30300 batches
#   completed 30300/32700 batches
#   → checkpointed after 30400 batches
#   completed 30400/32700 batches
#   → checkpointed after 30500 batches
#   completed 30500/32700 batches
#   → checkpointed after 30600 batches
#   completed 30600/32700 batches
#   → checkpointed after 30700 batches
#   completed 30700/32700 batches
#   → checkpointed after 30800 batches
#   completed 30800/32700 batches
#   → checkpointed after 30900 batches
#   completed 30900/32700 batches
#   → checkpointed after 31000 batches
#   completed 31000/32700 batches
#   → checkpointed after 31100 batches
#   completed 31100/32700 batches
#   → checkpointed after 31200 batches
#   completed 31200/32700 batches
#   → checkpointed after 31300 batches
#   completed 31300/32700 batches
#   → checkpointed after 31400 batches
#   completed 31400/32700 batches
#   → checkpointed after 31500 batches
#   completed 31500/32700 batches
#   → checkpointed after 31600 batches
#   completed 31600/32700 batches
#   → checkpointed after 31700 batches
#   completed 31700/32700 batches
#   → checkpointed after 31800 batches
#   completed 31800/32700 batches
#   → checkpointed after 31900 batches
#   completed 31900/32700 batches
#   → checkpointed after 32000 batches
#   completed 32000/32700 batches
#   → checkpointed after 32100 batches
#   completed 32100/32700 batches
#   → checkpointed after 32200 batches
#   completed 32200/32700 batches
#   → checkpointed after 32300 batches
#   completed 32300/32700 batches
#   → checkpointed after 32400 batches
#   completed 32400/32700 batches
#   → checkpointed after 32500 batches
#   completed 32500/32700 batches
#   → checkpointed after 32600 batches
#   completed 32600/32700 batches
#   → checkpointed after 32700 batches
#   completed 32700/32700 batches

# %%
graph_it = nx.read_graphml(f"/Users/wiktorrajca/Documents/GitHub/Data-Science-Honors-Thesis/code/procurement_graph_italy_build_full_clean.graphml")

# %%
screen_graph_multi_threads(graph_it)
# Out:
# 344110 nodes → 27532 pending batches across 4 scopes.
#   completed 1/27532 batches
#   → checkpointed after 100 batches
#   completed 100/27532 batches
#   → checkpointed after 200 batches
#   completed 200/27532 batches
#   → checkpointed after 300 batches
#   completed 300/27532 batches
#   → checkpointed after 400 batches
#   completed 400/27532 batches
#   → checkpointed after 500 batches
#   completed 500/27532 batches
#   → checkpointed after 600 batches
#   completed 600/27532 batches
#   → checkpointed after 700 batches
#   completed 700/27532 batches
#   → checkpointed after 800 batches
#   completed 800/27532 batches
#   → checkpointed after 900 batches
#   completed 900/27532 batches
#   → checkpointed after 1000 batches
#   completed 1000/27532 batches
#   → checkpointed after 1100 batches
#   completed 1100/27532 batches
#   → checkpointed after 1200 batches
#   completed 1200/27532 batches
#   → checkpointed after 1300 batches
#   completed 1300/27532 batches
#   → checkpointed after 1400 batches
#   completed 1400/27532 batches
#   → checkpointed after 1500 batches
#   completed 1500/27532 batches
#   → checkpointed after 1600 batches
#   completed 1600/27532 batches
#   → checkpointed after 1700 batches
#   completed 1700/27532 batches
#   → checkpointed after 1800 batches
#   completed 1800/27532 batches
#   → checkpointed after 1900 batches
#   completed 1900/27532 batches
#   → checkpointed after 2000 batches
#   completed 2000/27532 batches
#   → checkpointed after 2100 batches
#   completed 2100/27532 batches
#   → checkpointed after 2200 batches
#   completed 2200/27532 batches
#   → checkpointed after 2300 batches
#   completed 2300/27532 batches
#   → checkpointed after 2400 batches
#   completed 2400/27532 batches
#   → checkpointed after 2500 batches
#   completed 2500/27532 batches
#   → checkpointed after 2600 batches
#   completed 2600/27532 batches
#   → checkpointed after 2700 batches
#   completed 2700/27532 batches
#   → checkpointed after 2800 batches
#   completed 2800/27532 batches
#   → checkpointed after 2900 batches
#   completed 2900/27532 batches
#   → checkpointed after 3000 batches
#   completed 3000/27532 batches
# 2025-05-01 22:12:22,135 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:22,751 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:23,343 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:24,646 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:25,172 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:25,842 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:30,521 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:37,591 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:44,859 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:52,063 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:12:59,367 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:06,437 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:13,676 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:20,824 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:22,144 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:22,759 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:23,351 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:24,653 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:25,180 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:25,850 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:30,528 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:37,599 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:44,867 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:52,072 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:13:59,374 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:06,445 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:13,685 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:20,830 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:22,154 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:22,768 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:23,359 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:24,661 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:25,187 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:25,858 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:30,536 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:37,607 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:44,876 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:52,080 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:14:59,381 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:06,453 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:13,692 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:20,837 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:22,161 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:22,775 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:23,367 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
#   → checkpointed after 3100 batches
#   completed 3100/27532 batches
# 2025-05-01 22:15:24,670 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:25,194 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:25,866 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:30,542 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-01 22:15:37,615 ERROR: Scope sanctions batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
#   → checkpointed after 3200 batches
#   completed 3200/27532 batches
#   → checkpointed after 3300 batches
#   completed 3300/27532 batches
#   → checkpointed after 3400 batches
#   completed 3400/27532 batches
#   → checkpointed after 3500 batches
#   completed 3500/27532 batches
#   → checkpointed after 3600 batches
#   completed 3600/27532 batches
#   → checkpointed after 3700 batches
#   completed 3700/27532 batches
#   → checkpointed after 3800 batches
#   completed 3800/27532 batches
#   → checkpointed after 3900 batches
#   completed 3900/27532 batches
#   → checkpointed after 4000 batches
#   completed 4000/27532 batches
#   → checkpointed after 4100 batches
#   completed 4100/27532 batches
#   → checkpointed after 4200 batches
#   completed 4200/27532 batches
#   → checkpointed after 4300 batches
#   completed 4300/27532 batches
#   → checkpointed after 4400 batches
#   completed 4400/27532 batches
#   → checkpointed after 4500 batches
#   completed 4500/27532 batches
#   → checkpointed after 4600 batches
#   completed 4600/27532 batches
#   → checkpointed after 4700 batches
#   completed 4700/27532 batches
#   → checkpointed after 4800 batches
#   completed 4800/27532 batches
#   → checkpointed after 4900 batches
#   completed 4900/27532 batches
#   → checkpointed after 5000 batches
#   completed 5000/27532 batches
#   → checkpointed after 5100 batches
#   completed 5100/27532 batches
#   → checkpointed after 5200 batches
#   completed 5200/27532 batches
#   → checkpointed after 5300 batches
#   completed 5300/27532 batches
#   → checkpointed after 5400 batches
#   completed 5400/27532 batches
#   → checkpointed after 5500 batches
#   completed 5500/27532 batches
#   → checkpointed after 5600 batches
#   completed 5600/27532 batches
#   → checkpointed after 5700 batches
#   completed 5700/27532 batches
#   → checkpointed after 5800 batches
#   completed 5800/27532 batches
#   → checkpointed after 5900 batches
#   completed 5900/27532 batches
#   → checkpointed after 6000 batches
#   completed 6000/27532 batches
#   → checkpointed after 6100 batches
#   completed 6100/27532 batches
#   → checkpointed after 6200 batches
#   completed 6200/27532 batches
#   → checkpointed after 6300 batches
#   completed 6300/27532 batches
#   → checkpointed after 6400 batches
#   completed 6400/27532 batches
#   → checkpointed after 6500 batches
#   completed 6500/27532 batches
#   → checkpointed after 6600 batches
#   completed 6600/27532 batches
#   → checkpointed after 6700 batches
#   completed 6700/27532 batches
#   → checkpointed after 6800 batches
#   completed 6800/27532 batches
#   → checkpointed after 6900 batches
#   completed 6900/27532 batches
#   → checkpointed after 7000 batches
#   completed 7000/27532 batches
#   → checkpointed after 7100 batches
#   completed 7100/27532 batches
#   → checkpointed after 7200 batches
#   completed 7200/27532 batches
#   → checkpointed after 7300 batches
#   completed 7300/27532 batches
#   → checkpointed after 7400 batches
#   completed 7400/27532 batches
#   → checkpointed after 7500 batches
#   completed 7500/27532 batches
#   → checkpointed after 7600 batches
#   completed 7600/27532 batches
#   → checkpointed after 7700 batches
#   completed 7700/27532 batches
#   → checkpointed after 7800 batches
#   completed 7800/27532 batches
#   → checkpointed after 7900 batches
#   completed 7900/27532 batches
#   → checkpointed after 8000 batches
#   completed 8000/27532 batches
#   → checkpointed after 8100 batches
#   completed 8100/27532 batches
#   → checkpointed after 8200 batches
#   completed 8200/27532 batches
#   → checkpointed after 8300 batches
#   completed 8300/27532 batches
#   → checkpointed after 8400 batches
#   completed 8400/27532 batches
#   → checkpointed after 8500 batches
#   completed 8500/27532 batches
#   → checkpointed after 8600 batches
#   completed 8600/27532 batches
#   → checkpointed after 8700 batches
#   completed 8700/27532 batches
#   → checkpointed after 8800 batches
#   completed 8800/27532 batches
#   → checkpointed after 8900 batches
#   completed 8900/27532 batches
#   → checkpointed after 9000 batches
#   completed 9000/27532 batches
#   → checkpointed after 9100 batches
#   completed 9100/27532 batches
#   → checkpointed after 9200 batches
#   completed 9200/27532 batches
#   → checkpointed after 9300 batches
#   completed 9300/27532 batches
#   → checkpointed after 9400 batches
#   completed 9400/27532 batches
#   → checkpointed after 9500 batches
#   completed 9500/27532 batches
#   → checkpointed after 9600 batches
#   completed 9600/27532 batches
#   → checkpointed after 9700 batches
#   completed 9700/27532 batches
#   → checkpointed after 9800 batches
#   completed 9800/27532 batches
#   → checkpointed after 9900 batches
#   completed 9900/27532 batches
#   → checkpointed after 10000 batches
#   completed 10000/27532 batches
#   → checkpointed after 10100 batches
#   completed 10100/27532 batches
#   → checkpointed after 10200 batches
#   completed 10200/27532 batches
#   → checkpointed after 10300 batches
#   completed 10300/27532 batches
#   → checkpointed after 10400 batches
#   completed 10400/27532 batches
#   → checkpointed after 10500 batches
#   completed 10500/27532 batches
#   → checkpointed after 10600 batches
#   completed 10600/27532 batches
#   → checkpointed after 10700 batches
#   completed 10700/27532 batches
#   → checkpointed after 10800 batches
#   completed 10800/27532 batches
#   → checkpointed after 10900 batches
#   completed 10900/27532 batches
#   → checkpointed after 11000 batches
#   completed 11000/27532 batches
#   → checkpointed after 11100 batches
#   completed 11100/27532 batches
#   → checkpointed after 11200 batches
#   completed 11200/27532 batches
#   → checkpointed after 11300 batches
#   completed 11300/27532 batches
#   → checkpointed after 11400 batches
#   completed 11400/27532 batches
#   → checkpointed after 11500 batches
#   completed 11500/27532 batches
#   → checkpointed after 11600 batches
#   completed 11600/27532 batches
#   → checkpointed after 11700 batches
#   completed 11700/27532 batches
#   → checkpointed after 11800 batches
#   completed 11800/27532 batches
#   → checkpointed after 11900 batches
#   completed 11900/27532 batches
#   → checkpointed after 12000 batches
#   completed 12000/27532 batches
#   → checkpointed after 12100 batches
#   completed 12100/27532 batches
#   → checkpointed after 12200 batches
#   completed 12200/27532 batches
#   → checkpointed after 12300 batches
#   completed 12300/27532 batches
#   → checkpointed after 12400 batches
#   completed 12400/27532 batches
#   → checkpointed after 12500 batches
#   completed 12500/27532 batches
#   → checkpointed after 12600 batches
#   completed 12600/27532 batches
#   → checkpointed after 12700 batches
#   completed 12700/27532 batches
#   → checkpointed after 12800 batches
#   completed 12800/27532 batches
#   → checkpointed after 12900 batches
#   completed 12900/27532 batches
#   → checkpointed after 13000 batches
#   completed 13000/27532 batches
#   → checkpointed after 13100 batches
#   completed 13100/27532 batches
#   → checkpointed after 13200 batches
#   completed 13200/27532 batches
#   → checkpointed after 13300 batches
#   completed 13300/27532 batches
#   → checkpointed after 13400 batches
#   completed 13400/27532 batches
#   → checkpointed after 13500 batches
#   completed 13500/27532 batches
#   → checkpointed after 13600 batches
#   completed 13600/27532 batches
#   → checkpointed after 13700 batches
#   completed 13700/27532 batches
#   → checkpointed after 13800 batches
#   completed 13800/27532 batches
#   → checkpointed after 13900 batches
#   completed 13900/27532 batches
#   → checkpointed after 14000 batches
#   completed 14000/27532 batches
#   → checkpointed after 14100 batches
#   completed 14100/27532 batches
#   → checkpointed after 14200 batches
#   completed 14200/27532 batches
#   → checkpointed after 14300 batches
#   completed 14300/27532 batches
#   → checkpointed after 14400 batches
#   completed 14400/27532 batches
#   → checkpointed after 14500 batches
#   completed 14500/27532 batches
#   → checkpointed after 14600 batches
#   completed 14600/27532 batches
#   → checkpointed after 14700 batches
#   completed 14700/27532 batches
#   → checkpointed after 14800 batches
#   completed 14800/27532 batches
#   → checkpointed after 14900 batches
#   completed 14900/27532 batches
#   → checkpointed after 15000 batches
#   completed 15000/27532 batches
#   → checkpointed after 15100 batches
#   completed 15100/27532 batches
#   → checkpointed after 15200 batches
#   completed 15200/27532 batches
#   → checkpointed after 15300 batches
#   completed 15300/27532 batches
#   → checkpointed after 15400 batches
#   completed 15400/27532 batches
#   → checkpointed after 15500 batches
#   completed 15500/27532 batches
#   → checkpointed after 15600 batches
#   completed 15600/27532 batches
#   → checkpointed after 15700 batches
#   completed 15700/27532 batches
#   → checkpointed after 15800 batches
#   completed 15800/27532 batches
#   → checkpointed after 15900 batches
#   completed 15900/27532 batches
#   → checkpointed after 16000 batches
#   completed 16000/27532 batches
#   → checkpointed after 16100 batches
#   completed 16100/27532 batches
#   → checkpointed after 16200 batches
#   completed 16200/27532 batches
#   → checkpointed after 16300 batches
#   completed 16300/27532 batches
#   → checkpointed after 16400 batches
#   completed 16400/27532 batches
#   → checkpointed after 16500 batches
#   completed 16500/27532 batches
#   → checkpointed after 16600 batches
#   completed 16600/27532 batches
#   → checkpointed after 16700 batches
#   completed 16700/27532 batches
#   → checkpointed after 16800 batches
#   completed 16800/27532 batches
# 2025-05-02 00:18:18,798 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:19,112 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:19,637 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:20,265 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:20,884 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:21,680 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:22,971 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:23,505 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:24,219 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:30,913 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:41,295 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:18:51,892 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:02,245 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:12,698 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:18,806 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:19,119 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:19,644 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:20,272 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:20,890 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:21,687 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:22,979 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:23,512 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:24,228 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:30,921 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:41,303 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:19:51,900 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:02,252 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:12,707 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:18,814 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:19,127 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:19,653 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:20,281 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:20,899 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:21,694 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:22,987 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:23,520 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:24,236 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:30,930 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:41,311 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:20:51,909 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:02,259 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:12,715 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:18,824 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:19,135 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:19,662 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:20,290 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:20,907 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:21,704 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:22,996 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:23,528 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:24,244 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:30,937 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:41,321 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:21:51,916 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:02,266 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:12,723 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:18,832 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:19,145 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:19,669 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:20,299 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:20,915 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:21,711 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:23,004 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:23,537 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:24,250 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:30,945 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:41,328 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:22:51,922 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 00:23:02,275 ERROR: Scope regulatory batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
#   → checkpointed after 16900 batches
#   completed 16900/27532 batches
#   → checkpointed after 17000 batches
#   completed 17000/27532 batches
#   → checkpointed after 17100 batches
#   completed 17100/27532 batches
#   → checkpointed after 17200 batches
#   completed 17200/27532 batches
#   → checkpointed after 17300 batches
#   completed 17300/27532 batches
#   → checkpointed after 17400 batches
#   completed 17400/27532 batches
#   → checkpointed after 17500 batches
#   completed 17500/27532 batches
#   → checkpointed after 17600 batches
#   completed 17600/27532 batches
#   → checkpointed after 17700 batches
#   completed 17700/27532 batches
#   → checkpointed after 17800 batches
#   completed 17800/27532 batches
#   → checkpointed after 17900 batches
#   completed 17900/27532 batches
#   → checkpointed after 18000 batches
#   completed 18000/27532 batches
#   → checkpointed after 18100 batches
#   completed 18100/27532 batches
#   → checkpointed after 18200 batches
#   completed 18200/27532 batches
#   → checkpointed after 18300 batches
#   completed 18300/27532 batches
#   → checkpointed after 18400 batches
#   completed 18400/27532 batches
#   → checkpointed after 18500 batches
#   completed 18500/27532 batches
#   → checkpointed after 18600 batches
#   completed 18600/27532 batches
#   → checkpointed after 18700 batches
#   completed 18700/27532 batches
#   → checkpointed after 18800 batches
#   completed 18800/27532 batches
#   → checkpointed after 18900 batches
#   completed 18900/27532 batches
#   → checkpointed after 19000 batches
#   completed 19000/27532 batches
#   → checkpointed after 19100 batches
#   completed 19100/27532 batches
#   → checkpointed after 19200 batches
#   completed 19200/27532 batches
#   → checkpointed after 19300 batches
#   completed 19300/27532 batches
#   → checkpointed after 19400 batches
#   completed 19400/27532 batches
#   → checkpointed after 19500 batches
#   completed 19500/27532 batches
#   → checkpointed after 19600 batches
#   completed 19600/27532 batches
#   → checkpointed after 19700 batches
#   completed 19700/27532 batches
#   → checkpointed after 19800 batches
#   completed 19800/27532 batches
#   → checkpointed after 19900 batches
#   completed 19900/27532 batches
#   → checkpointed after 20000 batches
#   completed 20000/27532 batches
#   → checkpointed after 20100 batches
#   completed 20100/27532 batches
#   → checkpointed after 20200 batches
#   completed 20200/27532 batches
#   → checkpointed after 20300 batches
#   completed 20300/27532 batches
#   → checkpointed after 20400 batches
#   completed 20400/27532 batches
#   → checkpointed after 20500 batches
#   completed 20500/27532 batches
#   → checkpointed after 20600 batches
#   completed 20600/27532 batches
#   → checkpointed after 20700 batches
#   completed 20700/27532 batches
#   → checkpointed after 20800 batches
#   completed 20800/27532 batches
#   → checkpointed after 20900 batches
#   completed 20900/27532 batches
#   → checkpointed after 21000 batches
#   completed 21000/27532 batches
#   → checkpointed after 21100 batches
#   completed 21100/27532 batches
#   → checkpointed after 21200 batches
#   completed 21200/27532 batches
#   → checkpointed after 21300 batches
#   completed 21300/27532 batches
#   → checkpointed after 21400 batches
#   completed 21400/27532 batches
#   → checkpointed after 21500 batches
#   completed 21500/27532 batches
#   → checkpointed after 21600 batches
#   completed 21600/27532 batches
#   → checkpointed after 21700 batches
#   completed 21700/27532 batches
#   → checkpointed after 21800 batches
#   completed 21800/27532 batches
#   → checkpointed after 21900 batches
#   completed 21900/27532 batches
#   → checkpointed after 22000 batches
#   completed 22000/27532 batches
#   → checkpointed after 22100 batches
#   completed 22100/27532 batches
#   → checkpointed after 22200 batches
#   completed 22200/27532 batches
#   → checkpointed after 22300 batches
#   completed 22300/27532 batches
#   → checkpointed after 22400 batches
#   completed 22400/27532 batches
#   → checkpointed after 22500 batches
#   completed 22500/27532 batches
#   → checkpointed after 22600 batches
#   completed 22600/27532 batches
#   → checkpointed after 22700 batches
#   completed 22700/27532 batches
#   → checkpointed after 22800 batches
#   completed 22800/27532 batches
#   → checkpointed after 22900 batches
#   completed 22900/27532 batches
#   → checkpointed after 23000 batches
#   completed 23000/27532 batches
#   → checkpointed after 23100 batches
#   completed 23100/27532 batches
#   → checkpointed after 23200 batches
#   completed 23200/27532 batches
#   → checkpointed after 23300 batches
#   completed 23300/27532 batches
#   → checkpointed after 23400 batches
#   completed 23400/27532 batches
#   → checkpointed after 23500 batches
#   completed 23500/27532 batches
#   → checkpointed after 23600 batches
#   completed 23600/27532 batches
#   → checkpointed after 23700 batches
#   completed 23700/27532 batches
# 2025-05-02 01:43:46,116 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:46,551 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:47,075 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:47,710 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:48,233 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:49,164 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:50,349 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:50,978 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:51,735 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:43:58,192 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:08,596 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:19,095 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:29,451 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:39,727 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:46,123 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:46,558 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:47,083 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:47,718 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:48,241 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:49,171 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:50,357 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:50,986 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:51,742 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:44:58,200 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:08,616 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:19,122 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:29,481 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:39,759 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:46,156 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:46,592 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:47,117 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:47,750 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:48,275 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:49,204 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:50,391 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:51,020 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:51,774 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:45:58,234 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:08,639 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:19,134 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:29,494 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:39,770 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:46,166 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:46,602 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:47,125 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:47,759 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:48,282 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:49,212 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:50,401 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:51,029 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:51,783 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:46:58,242 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:08,648 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:19,144 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:29,501 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:39,777 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:46,173 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:46,608 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:47,134 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:47,768 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:48,290 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:49,221 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:50,406 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:51,036 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:51,791 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:47:58,249 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:48:08,657 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:48:19,151 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
# 2025-05-02 01:48:29,508 ERROR: Scope crime batch failed: HTTPConnectionPool(host='localhost', port=8000): Read timed out. (read timeout=60)
#   → checkpointed after 23800 batches
#   completed 23800/27532 batches
#   → checkpointed after 23900 batches
#   completed 23900/27532 batches
#   → checkpointed after 24000 batches
#   completed 24000/27532 batches
#   → checkpointed after 24100 batches
#   completed 24100/27532 batches
#   → checkpointed after 24200 batches
#   completed 24200/27532 batches
#   → checkpointed after 24300 batches
#   completed 24300/27532 batches
#   → checkpointed after 24400 batches
#   completed 24400/27532 batches
#   → checkpointed after 24500 batches
#   completed 24500/27532 batches
#   → checkpointed after 24600 batches
#   completed 24600/27532 batches
#   → checkpointed after 24700 batches
#   completed 24700/27532 batches
#   → checkpointed after 24800 batches
#   completed 24800/27532 batches
#   → checkpointed after 24900 batches
#   completed 24900/27532 batches
#   → checkpointed after 25000 batches
#   completed 25000/27532 batches
#   → checkpointed after 25100 batches
#   completed 25100/27532 batches
#   → checkpointed after 25200 batches
#   completed 25200/27532 batches
#   → checkpointed after 25300 batches
#   completed 25300/27532 batches
#   → checkpointed after 25400 batches
#   completed 25400/27532 batches
#   → checkpointed after 25500 batches
#   completed 25500/27532 batches
#   → checkpointed after 25600 batches
#   completed 25600/27532 batches
#   → checkpointed after 25700 batches
#   completed 25700/27532 batches
#   → checkpointed after 25800 batches
#   completed 25800/27532 batches
#   → checkpointed after 25900 batches
#   completed 25900/27532 batches
#   → checkpointed after 26000 batches
#   completed 26000/27532 batches
#   → checkpointed after 26100 batches
#   completed 26100/27532 batches
#   → checkpointed after 26200 batches
#   completed 26200/27532 batches
#   → checkpointed after 26300 batches
#   completed 26300/27532 batches
#   → checkpointed after 26400 batches
#   completed 26400/27532 batches
#   → checkpointed after 26500 batches
#   completed 26500/27532 batches
#   → checkpointed after 26600 batches
#   completed 26600/27532 batches
#   → checkpointed after 26700 batches
#   completed 26700/27532 batches
#   → checkpointed after 26800 batches
#   completed 26800/27532 batches
#   → checkpointed after 26900 batches
#   completed 26900/27532 batches
#   → checkpointed after 27000 batches
#   completed 27000/27532 batches
#   → checkpointed after 27100 batches
#   completed 27100/27532 batches
#   → checkpointed after 27200 batches
#   completed 27200/27532 batches
#   → checkpointed after 27300 batches
#   completed 27300/27532 batches
#   → checkpointed after 27400 batches
#   completed 27400/27532 batches
#   → checkpointed after 27500 batches
#   completed 27500/27532 batches
#   → checkpointed after 27532 batches
#   completed 27532/27532 batches
